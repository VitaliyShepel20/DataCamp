# %% [markdown]
# # Find the Months with the Highest Number of Crimes
# Using the crime_data list, you'll answer a common question that arises when dealing with crime data: How many crimes are committed each month?

# %%
crime_data = [['05/23/2016 05:35:00 PM',
  '024XX W DIVISION ST',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'true',
  '14'],
 ['03/26/2016 08:20:00 PM',
  '019XX W HOWARD ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '24'],
 ['04/25/2016 03:05:00 PM',
  '001XX W 79TH ST',
  'THEFT',
  'RETAIL THEFT',
  'DEPARTMENT STORE',
  'true',
  'false',
  '6'],
 ['04/26/2016 05:30:00 PM',
  '010XX N PINE AVE',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['06/19/2016 01:15:00 AM',
  '027XX W AUGUSTA BLVD',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '12'],
 ['05/28/2016 08:00:00 PM',
  '070XX S ASHLAND AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'GAS STATION',
  'false',
  'true',
  '7'],
 ['07/03/2016 03:43:00 PM',
  '0000X N STATE ST',
  'THEFT',
  'RETAIL THEFT',
  'OTHER',
  'false',
  'false',
  '1'],
 ['06/11/2016 06:55:00 PM',
  '044XX W MAYPOLE AVE',
  'PUBLIC PEACE VIOLATION',
  'RECKLESS CONDUCT',
  'STREET',
  'true',
  'false',
  '11'],
 ['10/04/2016 10:20:00 AM',
  '016XX W 63RD ST',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'true',
  'false',
  '7'],
 ['02/14/2017 09:00:00 PM',
  '018XX S WOOD ST',
  'CRIMINAL DAMAGE',
  'TO CITY OF CHICAGO PROPERTY',
  'PARK PROPERTY',
  'false',
  'false',
  '12'],
 ['03/01/2017 12:29:00 AM',
  '001XX N WESTERN AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'CURRENCY EXCHANGE',
  'false',
  'false',
  '12'],
 ['12/29/2016 10:00:00 AM',
  '071XX S NORMAL BLVD',
  'ASSAULT',
  'AGGRAVATED:KNIFE/CUTTING INSTR',
  'APARTMENT',
  'false',
  'true',
  '7'],
 ['01/25/2016 12:22:00 AM',
  '015XX N DAYTON ST',
  'BATTERY',
  'SIMPLE',
  'BAR OR TAVERN',
  'false',
  'false',
  '18'],
 ['05/20/2016 03:00:00 PM',
  '017XX N CLYBOURN AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT $300 AND UNDER',
  '',
  'false',
  'false',
  '18'],
 ['06/28/2016 12:30:00 AM',
  '111XX S ASHLAND AVE',
  'DECEPTIVE PRACTICE',
  'ILLEGAL USE CASH CARD',
  'BAR OR TAVERN',
  'false',
  'false',
  '22'],
 ['09/01/2016 03:00:00 AM',
  '085XX S LOOMIS BLVD',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '6'],
 ['01/09/2017 06:10:00 PM',
  '001XX W CHESTNUT ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '18'],
 ['10/21/2016 08:06:00 PM',
  '009XX S AUSTIN BLVD',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'NURSING HOME/RETIREMENT HOME',
  'false',
  'false',
  '15'],
 ['07/30/2016 08:34:00 PM',
  '103XX S VERNON AVE',
  'BATTERY',
  'SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '5'],
 ['11/27/2016 10:00:00 AM',
  '069XX W FOSTER AVE',
  'CRIM SEXUAL ASSAULT',
  'NON-AGGRAVATED',
  'RESIDENCE',
  'false',
  'false',
  '16'],
 ['06/09/2016 02:30:00 PM',
  '047XX S RICHMOND ST',
  'BATTERY',
  'SIMPLE',
  'SCHOOL, PUBLIC, GROUNDS',
  'false',
  'false',
  '9'],
 ['06/12/2016 11:50:00 AM',
  '027XX W 72ND ST',
  'NARCOTICS',
  'POSS: HEROIN(BRN/TAN)',
  'STREET',
  'true',
  'false',
  '8'],
 ['07/13/2016 03:30:00 AM',
  '050XX W THOMAS ST',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '15'],
 ['05/24/2016 10:55:00 PM',
  '074XX S STONY ISLAND AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'true',
  '3'],
 ['09/29/2016 04:00:00 AM',
  '113XX S FRONT AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'DRIVEWAY - RESIDENTIAL',
  'false',
  'false',
  '5'],
 ['07/09/2016 02:00:00 PM',
  '013XX E 52ND ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '2'],
 ['09/26/2016 12:05:00 AM',
  '035XX W 78TH ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'STREET',
  'false',
  'false',
  '8'],
 ['02/11/2017 04:00:00 PM',
  '021XX W BELMONT AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '19'],
 ['08/30/2016 09:30:00 AM',
  '066XX S ROCKWELL ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['09/29/2016 02:00:00 PM',
  '038XX W ROOSEVELT RD',
  'ASSAULT',
  'SIMPLE',
  'GAS STATION',
  'false',
  'false',
  '10'],
 ['06/27/2016 08:00:00 PM',
  '050XX S DR MARTIN LUTHER KING JR DR',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '2'],
 ['06/04/2016 08:45:00 PM',
  '088XX S ESCANABA AVE',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'true',
  'false',
  '4'],
 ['09/19/2016 06:05:00 PM',
  '094XX S VERNON AVE',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '6'],
 ['02/14/2017 08:00:00 PM',
  '042XX N KEDZIE AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '17'],
 ['05/20/2016 06:30:00 PM',
  '088XX S HOUSTON AVE',
  'OFFENSE INVOLVING CHILDREN',
  'OTHER OFFENSE',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['09/06/2016 01:00:00 PM',
  '003XX W 59TH PL',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['12/29/2016 05:00:00 PM',
  '067XX N MOZART ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '24'],
 ['09/17/2016 02:45:00 PM',
  '023XX S INDIANA AVE',
  'THEFT',
  'FROM BUILDING',
  'WAREHOUSE',
  'true',
  'false',
  '1'],
 ['11/19/2016 10:30:00 PM',
  '053XX N CALIFORNIA AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENCE',
  'false',
  'false',
  '20'],
 ['01/12/2016 03:43:00 PM',
  '069XX S WESTERN AVE',
  'LIQUOR LAW VIOLATION',
  'LIQUOR LICENSE VIOLATION',
  'TAVERN/LIQUOR STORE',
  'true',
  'false',
  '8'],
 ['01/14/2016 05:00:00 PM',
  '001XX E WACKER DR',
  'THEFT',
  'OVER $500',
  'CLEANING STORE',
  'false',
  'false',
  '1'],
 ['03/04/2017 02:00:00 AM',
  '065XX S ROCKWELL ST',
  'CRIMINAL TRESPASS',
  'TO RESIDENCE',
  'APARTMENT',
  'false',
  'false',
  '8'],
 ['01/13/2017 02:10:00 PM',
  '025XX W CATALPA AVE',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '20'],
 ['10/16/2016 02:30:00 AM',
  '003XX S STATE ST',
  'BATTERY',
  'SIMPLE',
  'CTA PLATFORM',
  'false',
  'false',
  '1'],
 ['01/22/2017 08:00:00 AM',
  '056XX W ADDISON ST',
  'BATTERY',
  'SIMPLE',
  'HOSPITAL BUILDING/GROUNDS',
  'false',
  'false',
  '16'],
 ['02/02/2016 12:40:00 PM',
  '076XX S HOMAN AVE',
  'ASSAULT',
  'PRO EMP HANDS NO/MIN INJURY',
  'SCHOOL, PUBLIC, BUILDING',
  'true',
  'false',
  '8'],
 ['07/21/2016 08:00:00 PM',
  '018XX W HUBBARD ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '12'],
 ['09/08/2016 12:09:00 AM',
  '047XX W VAN BUREN ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '11'],
 ['05/07/2016 03:15:00 PM',
  '004XX N MICHIGAN AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '18'],
 ['04/19/2016 10:35:00 PM',
  '033XX W MAYPOLE AVE',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'VEHICLE NON-COMMERCIAL',
  'true',
  'false',
  '11'],
 ['10/27/2016 11:04:00 AM',
  '012XX S WABASH AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'GAS STATION',
  'false',
  'false',
  '1'],
 ['08/27/2016 08:30:00 PM',
  '063XX S NORMAL BLVD',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '7'],
 ['01/27/2016 06:45:00 AM',
  '025XX S SPRINGFIELD AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '10'],
 ['02/17/2017 01:49:00 PM',
  '024XX W CHICAGO AVE',
  'THEFT',
  'RETAIL THEFT',
  'DRUG STORE',
  'false',
  'false',
  '12'],
 ['10/13/2016 05:45:00 PM',
  '078XX S WOLCOTT AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '6'],
 ['11/18/2016 10:00:00 AM',
  '087XX S CREGIER AVE',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'VACANT LOT/LAND',
  'false',
  'false',
  '4'],
 ['08/17/2016 11:00:00 PM',
  '054XX N KIMBALL AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '17'],
 ['07/11/2016 03:20:00 AM',
  '077XX S SOUTH SHORE DR',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'true',
  '4'],
 ['11/25/2016 12:35:00 AM',
  '025XX S SAWYER AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '10'],
 ['06/18/2016 05:30:00 AM',
  '036XX W 56TH PL',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '8'],
 ['02/15/2016 04:45:00 AM',
  '029XX N LOTUS AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '25'],
 ['12/17/2016 06:30:00 AM',
  '078XX S HAMILTON AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '6'],
 ['07/19/2016 12:00:00 AM',
  '032XX W 62ND PL',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['01/15/2017 04:00:00 PM',
  '035XX W 16TH ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
  'false',
  'false',
  '10'],
 ['05/18/2016 01:48:00 AM',
  '030XX S ARCHER AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESTAURANT',
  'false',
  'false',
  '9'],
 ['08/11/2016 04:30:00 AM',
  '036XX W JACKSON BLVD',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '11'],
 ['01/10/2016 02:40:00 PM',
  '068XX S THROOP ST',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '7'],
 ['02/14/2016 04:48:00 AM',
  '001XX W DIVISION ST',
  'DECEPTIVE PRACTICE',
  'ILLEGAL USE CASH CARD',
  'CURRENCY EXCHANGE',
  'false',
  'false',
  '18'],
 ['02/16/2017 01:20:00 PM',
  '002XX W ADAMS ST',
  'THEFT',
  'FROM BUILDING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['11/12/2016 06:15:00 PM',
  '013XX S CANAL ST',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '1'],
 ['08/28/2016 02:50:00 PM',
  '048XX W DAKIN ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '16'],
 ['01/11/2016 03:00:00 PM',
  '067XX N SAUGANASH AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '16'],
 ['11/20/2016 01:15:00 PM',
  '036XX S UNION AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'APARTMENT',
  'false',
  'false',
  '9'],
 ['02/25/2016 11:00:00 AM',
  '011XX S LAFLIN ST',
  'ASSAULT',
  'SIMPLE',
  'CHA PARKING LOT/GROUNDS',
  'false',
  'false',
  '12'],
 ['03/03/2017 07:00:00 PM',
  '058XX S ALBANY AVE',
  'OFFENSE INVOLVING CHILDREN',
  'SEX ASSLT OF CHILD BY FAM MBR',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['02/13/2017 10:45:00 AM',
  '014XX N LEAMINGTON AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '25'],
 ['09/23/2016 11:28:00 AM',
  '0000X W 87TH ST',
  'THEFT',
  'PURSE-SNATCHING',
  'CTA BUS',
  'false',
  'false',
  '6'],
 ['03/20/2016 12:57:00 PM',
  '096XX S PRINCETON AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '5'],
 ['01/14/2017 09:25:00 AM',
  '045XX S PRINCETON AVE',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
  'false',
  'false',
  '9'],
 ['07/22/2016 05:00:00 PM',
  '098XX S INGLESIDE AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '5'],
 ['03/23/2016 03:50:00 PM',
  '031XX W POLK ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '11'],
 ['03/27/2016 02:00:00 PM',
  '012XX W GREENLEAF AVE',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'false',
  '24'],
 ['08/10/2016 04:20:00 PM',
  '039XX S ELLIS AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '2'],
 ['09/22/2016 03:00:00 PM',
  '027XX N SPAULDING AVE',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'false',
  '14'],
 ['01/24/2016 08:32:00 PM',
  '092XX S PEORIA ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'true',
  'true',
  '22'],
 ['07/05/2016 05:30:00 PM',
  '005XX W LOCUST ST',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'CHA PARKING LOT/GROUNDS',
  'false',
  'false',
  '18'],
 ['07/29/2016 11:00:00 PM',
  '002XX N HALSTED ST',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '12'],
 ['10/01/2016 02:10:00 AM',
  '031XX W 16TH ST',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
  'APARTMENT',
  'true',
  'true',
  '10'],
 ['07/03/2016 04:15:00 AM',
  '053XX W LAKE ST',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '15'],
 ['07/17/2016 11:25:00 AM',
  '049XX W ST PAUL AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '25'],
 ['03/18/2016 07:10:00 AM',
  '005XX S KEDZIE AVE',
  'THEFT',
  '$500 AND UNDER',
  'CTA TRAIN',
  'false',
  'false',
  '11'],
 ['04/08/2016 12:49:00 PM',
  '017XX W 87TH ST',
  'BATTERY',
  'SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '6'],
 ['12/12/2016 12:00:00 PM',
  '006XX N PAULINA ST',
  'THEFT',
  'OVER $500',
  'CONSTRUCTION SITE',
  'false',
  'false',
  '12'],
 ['08/25/2016 06:10:00 PM',
  '037XX S VINCENNES AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '2'],
 ['04/15/2016 04:21:00 PM',
  '020XX W GARFIELD BLVD',
  'THEFT',
  '$500 AND UNDER',
  'GAS STATION',
  'false',
  'false',
  '9'],
 ['02/26/2016 06:00:00 PM',
  '056XX W MADISON ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'false',
  '15'],
 ['05/16/2016 02:15:00 PM',
  '002XX W MONROE ST',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '1'],
 ['04/07/2016 12:01:00 AM',
  '002XX N STATE ST',
  'THEFT',
  'FROM BUILDING',
  'HOTEL/MOTEL',
  'false',
  'false',
  '1'],
 ['08/24/2016 05:13:00 AM',
  '033XX W BARRY AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '14'],
 ['12/19/2016 07:00:00 AM',
  '017XX E 67TH ST',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['08/02/2016 10:00:00 AM',
  '050XX W ADAMS ST',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'STREET',
  'false',
  'false',
  '15'],
 ['01/20/2017 10:25:00 AM',
  '007XX N PULASKI RD',
  'ASSAULT',
  'SIMPLE',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '11'],
 ['11/09/2016 07:00:00 PM',
  '0000X E 95TH ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '5'],
 ['05/20/2016 05:00:00 PM',
  '020XX W le moyne st',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '14'],
 ['01/21/2017 04:17:00 PM',
  '064XX N CLARK ST',
  'THEFT',
  'RETAIL THEFT',
  'POLICE FACILITY/VEH PARKING LOT',
  'true',
  'false',
  '24'],
 ['01/24/2016 11:00:00 AM',
  '032XX S PULASKI RD',
  'BATTERY',
  'SIMPLE',
  'OTHER',
  'true',
  'false',
  '10'],
 ['04/26/2016 05:55:00 AM',
  '079XX S ESSEX AVE',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
  'APARTMENT',
  'false',
  'true',
  '4'],
 ['01/19/2017 06:00:00 PM',
  '044XX N WOLCOTT AVE',
  'THEFT',
  'OVER $500',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '19'],
 ['08/27/2016 03:43:00 AM',
  '073XX S YALE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '7'],
 ['07/18/2016 08:00:00 PM',
  '065XX S WASHTENAW AVE',
  'NARCOTICS',
  'POSS: SYNTHETIC DRUGS',
  'STREET',
  'true',
  'false',
  '8'],
 ['07/19/2016 02:15:00 PM',
  '013XX W LUNT AVE',
  'THEFT',
  'FROM BUILDING',
  'OTHER',
  'false',
  'false',
  '24'],
 ['11/01/2016 09:40:00 AM',
  '063XX S MAPLEWOOD AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'true',
  '8'],
 ['02/04/2016 06:30:00 AM',
  '057XX W CORNELIA AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '16'],
 ['07/27/2016 11:20:00 PM',
  '007XX N RIDGEWAY AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['03/09/2016 11:00:00 AM',
  '073XX W PRATT AVE',
  'PUBLIC PEACE VIOLATION',
  'OTHER VIOLATION',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '16'],
 ['07/11/2016 06:00:00 PM',
  '025XX W FLOURNOY ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '11'],
 ['02/13/2017 07:00:00 AM',
  '080XX S PERRY AVE',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '6'],
 ['02/12/2017 07:00:00 PM',
  '004XX W 104TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '22'],
 ['01/05/2017 05:45:00 PM',
  '028XX W OGDEN AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '10'],
 ['03/04/2017 02:00:00 PM',
  '031XX N CLARK ST',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '19'],
 ['01/29/2016 05:55:00 PM',
  '0000X E 111TH PL',
  'ASSAULT',
  'AGGRAVATED: OTHER DANG WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '5'],
 ['01/09/2016 12:28:00 AM',
  '003XX W 88TH ST',
  'OTHER OFFENSE',
  'OTHER VEHICLE OFFENSE',
  'STREET',
  'true',
  'false',
  '6'],
 ['07/08/2016 02:30:00 AM',
  '018XX W EVERGREEN AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '14'],
 ['06/26/2016 01:00:00 AM',
  '011XX N KARLOV AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'false',
  '11'],
 ['01/11/2017 09:00:00 AM',
  '006XX E 130TH ST',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'false',
  '5'],
 ['03/11/2016 07:20:00 PM',
  '095XX S WOODLAWN AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '5'],
 ['03/31/2016 11:10:00 AM',
  '050XX W MADISON ST',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['08/25/2016 12:07:00 PM',
  '050XX W CHICAGO AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '15'],
 ['04/13/2016 04:19:00 PM',
  '021XX W JACKSON BLVD',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'ALLEY',
  'true',
  'false',
  '12'],
 ['08/11/2016 04:00:00 PM',
  '073XX S HALSTED ST',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '7'],
 ['12/29/2016 07:30:00 AM',
  '019XX N CLYBOURN AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '18'],
 ['08/08/2016 09:00:00 AM',
  '0000X W JACKSON BLVD',
  'THEFT',
  '$500 AND UNDER',
  'CTA TRAIN',
  'false',
  'false',
  '1'],
 ['09/08/2016 12:01:00 AM',
  '015XX N SANDBURG TER',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '18'],
 ['02/05/2017 05:30:00 AM',
  '051XX W DIVERSEY AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '25'],
 ['01/05/2017 02:00:00 PM',
  '016XX E 50TH PL',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'APARTMENT',
  'false',
  'false',
  '2'],
 ['10/30/2016 07:45:00 AM',
  '113XX S MAY ST',
  'CRIMINAL TRESPASS',
  'TO RESIDENCE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'true',
  '22'],
 ['08/30/2016 02:30:00 PM',
  '019XX N CLARK ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '18'],
 ['07/06/2016 01:50:00 PM',
  '026XX N ELSTON AVE',
  'THEFT',
  'RETAIL THEFT',
  'DEPARTMENT STORE',
  'true',
  'false',
  '14'],
 ['12/12/2016 10:15:00 PM',
  '048XX S HOYNE AVE',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'VEHICLE NON-COMMERCIAL',
  'true',
  'false',
  '9'],
 ['07/28/2016 12:55:00 AM',
  '031XX W LOGAN BLVD',
  'BATTERY',
  'SIMPLE',
  'BAR OR TAVERN',
  'false',
  'false',
  '14'],
 ['06/10/2016 11:35:00 PM',
  '113XX S NORMAL AVE',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '22'],
 ['10/29/2016 02:07:00 AM',
  '019XX W MARQUETTE RD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '7'],
 ['11/07/2016 10:30:00 AM',
  '048XX W ALTGELD ST',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '25'],
 ['10/25/2016 03:35:00 AM',
  '087XX S STONY ISLAND AVE',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '4'],
 ['05/17/2016 11:00:00 AM',
  '058XX N ELSTON AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '16'],
 ['06/09/2016 08:05:00 PM',
  '0000X W WASHINGTON ST',
  'THEFT',
  '$500 AND UNDER',
  'SIDEWALK',
  'false',
  'false',
  '1'],
 ['05/25/2016 08:34:00 PM',
  '038XX W MADISON ST',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['09/23/2016 10:00:00 PM',
  '018XX N RIDGEWAY AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '25'],
 ['09/07/2016 06:20:00 PM',
  '016XX N DAMEN AVE',
  'THEFT',
  'RETAIL THEFT',
  'OTHER',
  'false',
  'false',
  '14'],
 ['02/02/2016 09:30:00 PM',
  '024XX W ARTHINGTON ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '11'],
 ['06/01/2016 09:00:00 AM',
  '051XX W ST PAUL AVE',
  'DECEPTIVE PRACTICE',
  'BOGUS CHECK',
  'RESIDENCE',
  'false',
  'false',
  '25'],
 ['05/21/2016 02:00:00 PM',
  '008XX N CICERO AVE',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '11'],
 ['12/03/2016 11:15:00 AM',
  '007XX S INDEPENDENCE BLVD',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '11'],
 ['09/23/2016 08:47:00 AM',
  '079XX S SACRAMENTO AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'RESIDENCE',
  'false',
  'true',
  '8'],
 ['04/08/2016 07:49:00 PM',
  '062XX S JUSTINE ST',
  'BURGLARY',
  'ATTEMPT FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['02/25/2016 08:00:00 AM',
  '002XX S LOTUS AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '15'],
 ['04/25/2016 10:00:00 AM',
  '008XX N ST LOUIS AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'APARTMENT',
  'false',
  'false',
  '11'],
 ['04/13/2016 02:25:00 AM',
  '026XX N MILWAUKEE AVE',
  'ASSAULT',
  'SIMPLE',
  'CTA STATION',
  'false',
  'false',
  '14'],
 ['05/21/2016 01:00:00 PM',
  '0000X S STATE ST',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'DEPARTMENT STORE',
  'false',
  'false',
  '1'],
 ['01/01/2017 02:39:00 AM',
  '061XX S CALIFORNIA AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'true',
  'false',
  '8'],
 ['02/23/2016 02:45:00 PM',
  '078XX S ASHLAND AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'true',
  'false',
  '6'],
 ['04/08/2016 09:00:00 AM',
  '028XX N MULLIGAN AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT $300 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '25'],
 ['10/22/2016 02:00:00 PM',
  '069XX S MAPLEWOOD AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'STREET',
  'false',
  'false',
  '8'],
 ['06/07/2016 09:03:00 PM',
  '002XX N SACRAMENTO BLVD',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'VACANT LOT/LAND',
  'true',
  'false',
  '12'],
 ['09/23/2016 10:00:00 PM',
  '046XX N CLIFTON AVE',
  'THEFT',
  '$500 AND UNDER',
  'OTHER',
  'false',
  'false',
  '19'],
 ['01/13/2017 05:00:00 AM',
  '006XX N MICHIGAN AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'COMMERCIAL / BUSINESS OFFICE',
  'false',
  'true',
  '18'],
 ['02/17/2016 01:00:00 PM',
  '036XX S WENTWORTH AVE',
  'DECEPTIVE PRACTICE',
  'COUNTERFEITING DOCUMENT',
  'STREET',
  'false',
  'false',
  '9'],
 ['05/12/2016 07:30:00 PM',
  '036XX N CENTRAL AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '16'],
 ['11/04/2016 01:00:00 PM',
  '080XX S DANTE AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['04/12/2016 06:25:00 PM',
  '011XX N CLARK ST',
  'THEFT',
  'POCKET-PICKING',
  'CTA TRAIN',
  'false',
  'false',
  '18'],
 ['01/14/2016 06:21:00 PM',
  '001XX S LARAMIE AVE',
  'NARCOTICS',
  'SOLICIT NARCOTICS ON PUBLICWAY',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '15'],
 ['11/15/2016 12:15:00 AM',
  '033XX N AVERS AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '17'],
 ['12/15/2016 09:00:00 AM',
  '013XX W LUNT AVE',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '24'],
 ['09/27/2016 08:00:00 PM',
  '132XX S AVENUE M',
  'THEFT',
  '$500 AND UNDER',
  'ALLEY',
  'false',
  'false',
  '4'],
 ['06/28/2016 01:00:00 AM',
  '045XX W THOMAS ST',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['09/10/2016 12:50:00 PM',
  '045XX W 57TH ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '8'],
 ['09/30/2016 05:18:00 PM',
  '039XX W FLOURNOY ST',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'STREET',
  'true',
  'false',
  '11'],
 ['03/24/2016 12:14:00 AM',
  '097XX S AVENUE L',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'true',
  'true',
  '4'],
 ['08/13/2016 08:25:00 PM',
  '007XX E 43RD ST',
  'DECEPTIVE PRACTICE',
  'THEFT OF LABOR/SERVICES',
  'OTHER',
  'true',
  'false',
  '2'],
 ['02/17/2017 06:00:00 PM',
  '021XX W NORTH AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '14'],
 ['08/08/2016 03:00:00 PM',
  '011XX N WASHTENAW AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '12'],
 ['08/16/2016 07:00:00 PM',
  '043XX W 28TH ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '10'],
 ['12/13/2016 12:45:00 AM',
  '020XX W CULLERTON ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'STREET',
  'false',
  'false',
  '12'],
 ['10/29/2016 04:00:00 AM',
  '030XX S DRAKE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '10'],
 ['07/05/2016 10:00:00 AM',
  '022XX W ARMITAGE AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '14'],
 ['01/30/2017 04:00:00 PM',
  '0000X N HALSTED ST',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '12'],
 ['06/18/2016 05:00:00 AM',
  '006XX W BELMONT AVE',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'STREET',
  'false',
  'false',
  '19'],
 ['02/17/2016 07:45:00 PM',
  '022XX W WARREN BLVD',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'APARTMENT',
  'false',
  'false',
  '12'],
 ['09/24/2016 07:30:00 PM',
  '031XX W FLOURNOY ST',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'STREET',
  'false',
  'false',
  '11'],
 ['10/24/2016 08:23:00 PM',
  '016XX E 71ST ST',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '3'],
 ['03/29/2016 10:16:00 AM',
  '014XX W 62ND ST',
  'ASSAULT',
  'AGGRAVATED: OTHER DANG WEAPON',
  'STREET',
  'false',
  'false',
  '7'],
 ['08/15/2016 07:36:00 PM',
  '008XX W RANDOLPH ST',
  'BATTERY',
  'SIMPLE',
  'BAR OR TAVERN',
  'false',
  'false',
  '12'],
 ['05/07/2016 02:00:00 PM',
  '0000X N MICHIGAN AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '1'],
 ['01/30/2016 12:17:00 PM',
  '031XX W IRVING PARK RD',
  'NARCOTICS',
  'MANU/DELIVER:CRACK',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '17'],
 ['04/24/2016 10:44:00 PM',
  '108XX S HOXIE AVE',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'false',
  '4'],
 ['10/09/2016 08:30:00 PM',
  '003XX S DEARBORN ST',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'OTHER',
  'false',
  'false',
  '1'],
 ['02/26/2016 11:20:00 AM',
  '058XX S SHIELDS AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'false',
  '7'],
 ['07/31/2016 09:30:00 AM',
  '012XX N HARDING AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '25'],
 ['10/22/2016 10:30:00 AM',
  '018XX W LAWRENCE AVE',
  'THEFT',
  'FROM BUILDING',
  'ATHLETIC CLUB',
  'false',
  'false',
  '20'],
 ['05/15/2016 01:00:00 PM',
  '060XX S WOLCOTT AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '7'],
 ['05/11/2016 11:00:00 PM',
  '006XX N MAY ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '12'],
 ['02/09/2017 09:00:00 PM',
  '010XX E MARQUETTE RD',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['02/15/2017 01:00:00 AM',
  '025XX S SPRINGFIELD AVE',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'APARTMENT',
  'false',
  'true',
  '10'],
 ['08/24/2016 12:14:00 AM',
  '107XX S WABASH AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '5'],
 ['11/26/2016 12:35:00 AM',
  '085XX S ESCANABA AVE',
  'PUBLIC PEACE VIOLATION',
  'RECKLESS CONDUCT',
  'STREET',
  'true',
  'false',
  '4'],
 ['06/16/2016 01:30:00 PM',
  '002XX S MICHIGAN AVE',
  'THEFT',
  'FROM BUILDING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['02/04/2016 12:50:00 PM',
  '085XX S DREXEL AVE',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '6'],
 ['08/16/2016 07:00:00 AM',
  '015XX E 53RD ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '2'],
 ['01/22/2017 01:00:00 PM',
  '005XX W 111TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '22'],
 ['11/20/2016 03:30:00 PM',
  '051XX W MEDILL AVE',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '25'],
 ['02/03/2016 07:30:00 PM',
  '090XX S LOOMIS ST',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '22'],
 ['07/26/2016 03:30:00 PM',
  '003XX S STATE ST',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'STREET',
  'false',
  'false',
  '1'],
 ['06/14/2016 06:00:00 PM',
  '048XX N CICERO AVE',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '16'],
 ['03/27/2016 12:00:00 AM',
  '067XX W RAVEN ST',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '16'],
 ['09/01/2016 08:00:00 AM',
  '012XX W ARTHUR AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT $300 AND UNDER',
  '',
  'false',
  'false',
  '24'],
 ['03/16/2016 01:30:00 AM',
  '030XX N HARLEM AVE',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '25'],
 ['05/25/2016 11:40:00 PM',
  '0000X E 26TH ST',
  'BURGLARY',
  'HOME INVASION',
  'RESIDENCE',
  'false',
  'false',
  '1'],
 ['08/18/2016 11:50:00 PM',
  '059XX N CLARK ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'COMMERCIAL / BUSINESS OFFICE',
  'false',
  'false',
  '20'],
 ['02/03/2017 06:35:00 PM',
  '0000X S STATE ST',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '1'],
 ['09/22/2016 08:00:00 AM',
  '001XX N CENTRAL AVE',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '15'],
 ['04/02/2016 12:40:00 PM',
  '010XX N SPRINGFIELD AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['01/02/2017 12:00:00 PM',
  '013XX W 13TH ST',
  'OFFENSE INVOLVING CHILDREN',
  'OTHER OFFENSE',
  'CHA APARTMENT',
  'false',
  'true',
  '12'],
 ['05/27/2016 08:09:00 AM',
  '063XX S INGLESIDE AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'APARTMENT',
  'false',
  'true',
  '3'],
 ['01/02/2016 01:30:00 PM',
  '001XX W MONROE ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'HOTEL/MOTEL',
  'false',
  'false',
  '1'],
 ['01/03/2016 02:45:00 PM',
  '008XX N LECLAIRE AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '15'],
 ['01/25/2016 11:35:00 PM',
  '022XX W DEVON AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '24'],
 ['11/22/2016 08:30:00 PM',
  '073XX S BENNETT AVE',
  'ROBBERY',
  'AGGRAVATED VEHICULAR HIJACKING',
  'STREET',
  'false',
  'false',
  '3'],
 ['03/06/2016 06:19:00 PM',
  '079XX S LAFAYETTE AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '6'],
 ['02/27/2016 02:25:00 PM',
  '082XX W GREGORY ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '16'],
 ['12/18/2016 04:00:00 PM',
  '058XX N WAYNE AVE',
  'THEFT',
  'FROM BUILDING',
  'OTHER',
  'false',
  'false',
  '20'],
 ['11/04/2016 12:01:00 AM',
  '010XX N ROCKWELL ST',
  'OTHER OFFENSE',
  'OTHER VEHICLE OFFENSE',
  'STREET',
  'false',
  'true',
  '12'],
 ['09/12/2016 06:00:00 PM',
  '066XX S TROY ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '8'],
 ['03/04/2016 06:05:00 PM',
  '085XX S COTTAGE GROVE AVE',
  'THEFT',
  'RETAIL THEFT',
  'DEPARTMENT STORE',
  'true',
  'false',
  '6'],
 ['01/02/2017 10:00:00 AM',
  '048XX N KIMBALL AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '17'],
 ['12/23/2016 01:40:00 PM',
  '083XX S STEWART AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'true',
  'false',
  '6'],
 ['08/23/2016 08:00:00 PM',
  '019XX W 23RD ST',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'STREET',
  'false',
  'false',
  '10'],
 ['08/03/2016 03:00:00 PM',
  '015XX E 75TH ST',
  'THEFT',
  '$500 AND UNDER',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '3'],
 ['02/13/2017 08:11:00 PM',
  '117XX S INDIANA AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'true',
  'true',
  '5'],
 ['09/26/2016 03:15:00 PM',
  '063XX S GREEN ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '7'],
 ['12/06/2016 09:54:00 PM',
  '035XX W 25TH ST',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'VEHICLE NON-COMMERCIAL',
  'true',
  'false',
  '10'],
 ['01/05/2016 01:40:00 AM',
  '020XX W TOUHY AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '24'],
 ['07/09/2016 04:00:00 PM',
  '015XX W RANDOLPH ST',
  'THEFT',
  '$500 AND UNDER',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '12'],
 ['11/12/2016 01:00:00 AM',
  '077XX S CLAREMONT AVE',
  'OFFENSE INVOLVING CHILDREN',
  'SEX ASSLT OF CHILD BY FAM MBR',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['07/29/2016 02:00:00 PM',
  '008XX S CICERO AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['07/19/2016 09:26:00 PM',
  '109XX S DOTY AVE E',
  'THEFT',
  'OVER $500',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '5'],
 ['01/14/2017 09:00:00 PM',
  '100XX S ABERDEEN ST',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'false',
  '22'],
 ['12/29/2016 08:30:00 AM',
  '010XX N LAVERGNE AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'true',
  '15'],
 ['03/03/2016 01:48:00 AM',
  '014XX W MONTROSE AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESTAURANT',
  'false',
  'false',
  '19'],
 ['03/12/2016 12:30:00 PM',
  '011XX S CLARK ST',
  'THEFT',
  '$500 AND UNDER',
  'DEPARTMENT STORE',
  'false',
  'false',
  '1'],
 ['01/25/2016 01:00:00 PM',
  '005XX S KOSTNER AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '11'],
 ['01/16/2017 02:28:00 PM',
  '072XX S PERRY AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '7'],
 ['05/28/2016 12:40:00 AM',
  '053XX S MELVINA AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '8'],
 ['09/22/2016 02:32:00 AM',
  '076XX S HALSTED ST',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'GAS STATION',
  'true',
  'false',
  '6'],
 ['11/03/2016 07:00:00 AM',
  '032XX S KARLOV AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '10'],
 ['10/13/2016 09:55:00 PM',
  '031XX W HARRISON ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '11'],
 ['08/22/2016 04:00:00 PM',
  '089XX S BUFFALO AVE',
  'OFFENSE INVOLVING CHILDREN',
  'CHILD ABANDONMENT',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '4'],
 ['02/19/2016 05:00:00 PM',
  '069XX S YALE AVE',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '7'],
 ['07/11/2016 04:00:00 AM',
  '054XX S WINCHESTER AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '9'],
 ['01/15/2017 02:00:00 PM',
  '080XX S COLFAX AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '4'],
 ['06/02/2016 09:00:00 PM',
  '043XX S INDIANA AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '2'],
 ['02/17/2016 02:00:00 AM',
  '082XX S STATE ST',
  'DECEPTIVE PRACTICE',
  'COUNTERFEITING DOCUMENT',
  'GAS STATION',
  'false',
  'false',
  '6'],
 ['10/08/2016 07:27:00 PM',
  '095XX S GREEN ST',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'STREET',
  'false',
  'false',
  '22'],
 ['07/17/2016 02:40:00 PM',
  '026XX N LINDER AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'ALLEY',
  'false',
  'true',
  '25'],
 ['08/03/2016 08:00:00 AM',
  '021XX N STAVE ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '14'],
 ['01/31/2017 09:00:00 PM',
  '062XX N MAGNOLIA AVE',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '24'],
 ['08/25/2016 01:00:00 AM',
  '024XX W PENSACOLA AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'false',
  '19'],
 ['04/09/2016 10:38:00 PM',
  '021XX W GRACE ST',
  'BATTERY',
  'SIMPLE',
  'TAVERN/LIQUOR STORE',
  'true',
  'false',
  '19'],
 ['03/11/2016 07:59:00 PM',
  '052XX W POLK ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '15'],
 ['10/25/2016 10:35:00 PM',
  '090XX S ABERDEEN ST',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '22'],
 ['10/24/2016 01:00:00 PM',
  '038XX N AVERS AVE',
  'CRIMINAL DAMAGE',
  'CRIMINAL DEFACEMENT',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '17'],
 ['07/19/2016 02:30:00 AM',
  '012XX S SAWYER AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'OTHER',
  'false',
  'false',
  '10'],
 ['02/27/2017 07:00:00 PM',
  '019XX W 19TH ST',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '12'],
 ['02/23/2016 03:00:00 PM',
  '0000X E CHICAGO AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '18'],
 ['02/05/2016 06:00:00 AM',
  '064XX S WESTERN AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '8'],
 ['08/29/2016 03:19:00 PM',
  '007XX N MONTICELLO AVE',
  'NARCOTICS',
  'POSS: CRACK',
  'VEHICLE NON-COMMERCIAL',
  'true',
  'false',
  '11'],
 ['12/28/2016 10:25:00 AM',
  '071XX S JEFFERY BLVD',
  'ASSAULT',
  'SIMPLE',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '3'],
 ['01/28/2017 05:30:00 PM',
  '047XX N CENTRAL PARK AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '17'],
 ['10/06/2016 07:30:00 PM',
  '003XX N LEAVITT ST',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '12'],
 ['08/09/2016 09:30:00 PM',
  '017XX N MONITOR AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '25'],
 ['08/24/2016 05:55:00 PM',
  '044XX S INDIANA AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'true',
  '2'],
 ['01/30/2016 01:37:00 PM',
  '091XX S STEWART AVE',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '6'],
 ['02/04/2017 09:00:00 PM',
  '006XX W HARRISON ST',
  'THEFT',
  '$500 AND UNDER',
  'OTHER',
  'false',
  'false',
  '1'],
 ['09/12/2016 01:15:00 AM',
  '013XX W ESTES AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '24'],
 ['09/29/2016 02:40:00 PM',
  '018XX W FULLERTON AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'true',
  'false',
  '19'],
 ['11/09/2016 06:10:00 PM',
  '035XX S WOOD ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '9'],
 ['08/03/2016 06:18:00 PM',
  '010XX W DIVERSEY PKWY',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'ATHLETIC CLUB',
  'false',
  'false',
  '19'],
 ['07/28/2016 02:00:00 AM',
  '058XX S WELLS ST',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '7'],
 ['02/25/2016 03:27:47 PM',
  '035XX W CHICAGO AVE',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'APARTMENT',
  'true',
  'false',
  '11'],
 ['08/28/2016 10:47:00 PM',
  '122XX S LOWE AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['09/05/2016 12:20:00 AM',
  '022XX E 70TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '3'],
 ['03/08/2016 02:45:00 PM',
  '021XX N LONG AVE',
  'PUBLIC PEACE VIOLATION',
  'RECKLESS CONDUCT',
  'SCHOOL, PUBLIC, BUILDING',
  'true',
  'false',
  '25'],
 ['06/24/2016 06:05:00 PM',
  '002XX W GARFIELD BLVD',
  'BATTERY',
  'PRO EMP HANDS NO/MIN INJURY',
  'RESTAURANT',
  'false',
  'false',
  '9'],
 ['09/23/2016 09:00:00 AM',
  '001XX W MAPLE ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '18'],
 ['03/12/2016 04:00:00 PM',
  '011XX N CHRISTIANA AVE',
  'BATTERY',
  'SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '11'],
 ['10/04/2016 11:40:00 PM',
  '002XX W 91ST ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '6'],
 ['12/29/2016 10:40:00 PM',
  '026XX W ROSEMONT AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'STREET',
  'true',
  'false',
  '24'],
 ['12/12/2016 11:38:00 PM',
  '061XX S KIMBARK AVE',
  'ASSAULT',
  'SIMPLE',
  'OTHER',
  'false',
  'true',
  '3'],
 ['06/13/2016 08:30:00 AM',
  '082XX S LANGLEY AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '6'],
 ['10/09/2016 03:29:00 PM',
  '016XX S HARDING AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'false',
  'true',
  '10'],
 ['05/03/2016 11:33:00 PM',
  '026XX W 23RD PL',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '10'],
 ['01/16/2016 11:00:00 PM',
  '080XX S SOUTH SHORE DR',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['05/29/2016 03:00:00 PM',
  '049XX W POTOMAC AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'ALLEY',
  'false',
  'false',
  '25'],
 ['04/24/2016 07:45:00 PM',
  '033XX S THROOP ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'true',
  '9'],
 ['01/01/2016 04:25:00 AM',
  '030XX W CULLERTON ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '10'],
 ['02/05/2017 05:45:00 AM',
  '018XX W SUPERIOR ST',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'STREET',
  'false',
  'false',
  '12'],
 ['01/18/2017 08:00:00 PM',
  '019XX W OHIO ST',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '12'],
 ['09/18/2016 12:01:00 AM',
  '021XX N SHEFFIELD AVE',
  'THEFT',
  'OVER $500',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '18'],
 ['07/02/2016 11:00:00 PM',
  '040XX W DEVON AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '17'],
 ['09/19/2016 08:15:00 PM',
  '057XX S THROOP ST',
  'PUBLIC PEACE VIOLATION',
  'RECKLESS CONDUCT',
  'STREET',
  'true',
  'false',
  '7'],
 ['01/03/2017 04:00:00 PM',
  '076XX S CICERO AVE',
  'ASSAULT',
  'SIMPLE',
  'RESTAURANT',
  'false',
  'false',
  '8'],
 ['08/05/2016 02:40:00 PM',
  '118XX S LONGWOOD DR',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '22'],
 ['08/06/2016 12:01:00 AM',
  '069XX S OGLESBY AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'OTHER',
  'false',
  'false',
  '3'],
 ['07/21/2016 07:00:00 AM',
  '072XX N DAMEN AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '24'],
 ['11/17/2016 07:30:00 PM',
  '045XX N CALIFORNIA AVE',
  'CRIMINAL TRESPASS',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '17'],
 ['08/04/2016 04:00:00 PM',
  '061XX S WOLCOTT AVE',
  'THEFT',
  'FROM BUILDING',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '7'],
 ['01/11/2016 01:05:00 AM',
  '083XX S HERMITAGE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '6'],
 ['01/24/2016 01:55:00 AM',
  '006XX E 69TH ST',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
  'CHA APARTMENT',
  'true',
  'false',
  '3'],
 ['04/03/2016 01:40:00 AM',
  '013XX W BELLE PLAINE AVE',
  'DECEPTIVE PRACTICE',
  'ILLEGAL USE CASH CARD',
  'RESIDENCE',
  'false',
  'false',
  '19'],
 ['09/09/2016 08:11:00 PM',
  '111XX S WENTWORTH AVE',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'true',
  'false',
  '5'],
 ['09/23/2016 08:53:00 AM',
  '039XX W GLADYS AVE',
  'NARCOTICS',
  'ATTEMPT POSSESSION NARCOTICS',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['10/21/2016 09:30:00 PM',
  '003XX S STATE ST',
  'THEFT',
  'FROM BUILDING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['01/27/2017 09:00:00 AM',
  '081XX S ELLIS AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '6'],
 ['03/27/2016 03:00:00 PM',
  '094XX S HALSTED ST',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '22'],
 ['02/14/2017 10:15:00 PM',
  '012XX N HARDING AVE',
  'NARCOTICS',
  'POSS: CRACK',
  'STREET',
  'true',
  'false',
  '25'],
 ['01/31/2017 05:05:00 AM',
  '051XX W CHICAGO AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'CTA BUS',
  'false',
  'false',
  '15'],
 ['02/21/2016 03:30:00 AM',
  '076XX S EMERALD AVE',
  'BATTERY',
  'AGGRAVATED:KNIFE/CUTTING INSTR',
  'RESIDENCE',
  'false',
  'true',
  '6'],
 ['10/13/2016 12:30:00 PM',
  '006XX W CORNELIA AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'false',
  '19'],
 ['06/26/2016 10:43:00 PM',
  '034XX W DICKENS AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '14'],
 ['01/26/2017 08:06:00 AM',
  '028XX S KILDARE AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '10'],
 ['08/15/2016 07:30:00 PM',
  '012XX W 31ST ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '9'],
 ['01/05/2016 07:00:00 PM',
  '027XX W SUPERIOR ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '12'],
 ['08/22/2016 03:00:00 PM',
  '102XX S BENSLEY AVE',
  'THEFT',
  'OVER $500',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['10/12/2016 11:30:00 AM',
  '038XX S KEDZIE AVE',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'true',
  '9'],
 ['08/24/2016 03:01:00 PM',
  '126XX S HALSTED ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '5'],
 ['05/14/2016 12:00:00 PM',
  '0000X W 95TH ST',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'HIGHWAY/EXPRESSWAY',
  'true',
  'false',
  '6'],
 ['05/12/2016 10:45:00 PM',
  '006XX N LOCKWOOD AVE',
  'GAMBLING',
  'GAME/DICE',
  'SIDEWALK',
  'true',
  'false',
  '15'],
 ['12/03/2016 10:30:00 PM',
  '036XX E 118TH ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'DEPARTMENT STORE',
  'false',
  'false',
  '4'],
 ['04/02/2016 10:00:00 AM',
  '040XX W 61ST ST',
  'BATTERY',
  'AGGRAVATED: OTHER FIREARM',
  'ALLEY',
  'false',
  'false',
  '8'],
 ['02/23/2016 10:10:00 PM',
  '067XX S WESTERN AVE',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'STREET',
  'true',
  'false',
  '8'],
 ['02/22/2017 11:00:00 AM',
  '005XX W NORTH AVE',
  'THEFT',
  'OVER $500',
  'OTHER',
  'false',
  'false',
  '18'],
 ['10/26/2016 10:00:00 AM',
  '056XX W CORCORAN PL',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '15'],
 ['02/24/2016 07:00:00 PM',
  '021XX S LUMBER ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '12'],
 ['03/03/2017 10:30:00 AM',
  '011XX W FULTON MARKET',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '12'],
 ['10/05/2016 09:00:00 AM',
  '130XX S CHAMPLAIN AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '5'],
 ['08/16/2016 12:00:00 AM',
  '013XX N AUSTIN BLVD',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '25'],
 ['07/16/2016 08:04:00 PM',
  '015XX S CENTRAL PARK AVE',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '10'],
 ['01/05/2017 10:15:00 AM',
  '007XX E 47TH ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '2'],
 ['09/25/2016 11:02:00 AM',
  '067XX S STONY ISLAND AVE',
  'ASSAULT',
  'SIMPLE',
  'RESTAURANT',
  'false',
  'false',
  '3'],
 ['10/04/2016 06:10:00 PM',
  '029XX N CLARK ST',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '19'],
 ['05/31/2016 10:00:00 AM',
  '033XX W FILLMORE ST',
  'NARCOTICS',
  'POSS: CANNABIS MORE THAN 30GMS',
  'POLICE FACILITY/VEH PARKING LOT',
  'true',
  'false',
  '11'],
 ['09/12/2016 01:30:00 PM',
  '055XX W GLADYS AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '15'],
 ['08/04/2016 01:42:00 PM',
  '023XX W JACKSON BLVD',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '12'],
 ['08/25/2016 08:30:00 AM',
  '102XX S CRANDON AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'true',
  '4'],
 ['02/24/2017 10:15:00 PM',
  '051XX S LOCKWOOD AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['05/26/2016 06:30:00 PM',
  '010XX N ST LOUIS AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'true',
  'true',
  '11'],
 ['04/14/2016 10:00:00 AM',
  '006XX N CENTRAL AVE',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'true',
  '15'],
 ['07/29/2016 10:50:00 PM',
  '006XX S HOYNE AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '12'],
 ['09/29/2016 11:33:00 PM',
  '001XX E 111TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['03/10/2016 10:50:00 AM',
  '034XX W CHICAGO AVE',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'ALLEY',
  'true',
  'false',
  '11'],
 ['02/20/2016 12:20:00 PM',
  '053XX W HURON ST',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['12/03/2016 10:00:00 AM',
  '066XX S WOODLAWN AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT $300 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['09/16/2016 05:00:00 PM',
  '023XX N GREENVIEW AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'CONSTRUCTION SITE',
  'false',
  'false',
  '18'],
 ['04/12/2016 10:00:00 PM',
  '004XX E NORTH WATER ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '18'],
 ['08/28/2016 09:04:00 PM',
  '010XX S INDEPENDENCE BLVD',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '11'],
 ['07/02/2016 05:04:00 PM',
  '006XX W 63RD ST',
  'THEFT',
  'RETAIL THEFT',
  'DRUG STORE',
  'true',
  'false',
  '7'],
 ['04/01/2016 03:00:00 PM',
  '066XX W GEORGE ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '25'],
 ['01/16/2016 03:42:00 PM',
  '044XX W NORTH AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '25'],
 ['08/22/2016 01:45:00 AM',
  '033XX N HARDING AVE',
  'CRIMINAL TRESPASS',
  'TO RESIDENCE',
  'RESIDENCE',
  'true',
  'true',
  '17'],
 ['01/29/2016 02:50:00 PM',
  '083XX S ASHLAND AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '6'],
 ['09/11/2016 01:59:00 PM',
  '078XX S STEWART AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '6'],
 ['05/16/2016 01:00:00 PM',
  '016XX W 59TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '7'],
 ['04/14/2016 09:30:00 AM',
  '032XX W WILSON AVE',
  'MOTOR VEHICLE THEFT',
  'THEFT/RECOVERY: AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '17'],
 ['01/07/2017 10:00:00 PM',
  '055XX S THROOP ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '7'],
 ['09/02/2016 01:40:00 PM',
  '001XX N STATE ST',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '1'],
 ['07/31/2016 08:49:00 PM',
  '026XX W LE MOYNE ST',
  'CRIMINAL DAMAGE',
  'TO CITY OF CHICAGO PROPERTY',
  'STREET',
  'false',
  'false',
  '14'],
 ['10/03/2016 09:00:00 PM',
  '020XX W 69TH ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '7'],
 ['09/20/2016 08:30:00 PM',
  '0000X W 112TH ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'DRIVEWAY - RESIDENTIAL',
  'false',
  'false',
  '5'],
 ['07/11/2016 11:00:00 AM',
  '063XX S MOZART ST',
  'ROBBERY',
  'ARMED:KNIFE/CUTTING INSTRUMENT',
  'STREET',
  'false',
  'false',
  '8'],
 ['02/19/2016 06:00:00 PM',
  '051XX N MOODY AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '16'],
 ['01/07/2016 11:20:00 PM',
  '026XX W LITHUANIAN PLAZA CT',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'true',
  'true',
  '8'],
 ['04/09/2016 12:01:00 AM',
  '004XX N ST LOUIS AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '11'],
 ['03/01/2016 09:25:00 AM',
  '010XX N SPRINGFIELD AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '11'],
 ['05/06/2016 10:00:00 PM',
  '015XX E 62ND ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['10/17/2016 10:22:00 PM',
  '066XX S WENTWORTH AVE',
  'CONCEALED CARRY LICENSE VIOLATION',
  'OTHER',
  'GAS STATION',
  'true',
  'false',
  '7'],
 ['02/09/2017 08:00:00 PM',
  '014XX W WEBSTER AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '18'],
 ['05/26/2016 02:00:00 PM',
  '067XX S JEFFERY BLVD',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '3'],
 ['10/27/2016 09:30:00 AM',
  '039XX S CALIFORNIA AVE',
  'ASSAULT',
  'PRO EMP HANDS NO/MIN INJURY',
  'JAIL / LOCK-UP FACILITY',
  'true',
  'false',
  '9'],
 ['05/31/2016 01:30:00 AM',
  '089XX S MAY ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '22'],
 ['10/30/2016 01:20:00 PM',
  '033XX W 61ST PL',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '8'],
 ['11/19/2016 09:00:00 AM',
  '057XX N MAPLEWOOD AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '20'],
 ['01/06/2016 08:01:00 AM',
  '083XX S STEWART AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'true',
  '6'],
 ['03/18/2016 04:30:00 PM',
  '024XX W 83RD ST',
  'ASSAULT',
  'AGGRAVATED: OTHER DANG WEAPON',
  'STREET',
  'true',
  'false',
  '8'],
 ['01/17/2017 07:00:00 PM',
  '042XX W CERMAK RD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '10'],
 ['10/31/2016 02:18:00 AM',
  '059XX S WOLCOTT AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'true',
  '7'],
 ['02/04/2016 05:32:00 PM',
  '011XX N CLEVELAND AVE',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '18'],
 ['03/30/2016 08:14:34 PM',
  '014XX S KENNETH AVE',
  'NARCOTICS',
  'POSS: HALLUCINOGENS',
  'RESIDENCE',
  'true',
  'false',
  '10'],
 ['07/21/2016 01:00:00 PM',
  '072XX S SOUTH SHORE DR',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'OTHER',
  'false',
  'false',
  '3'],
 ['11/27/2016 02:15:00 PM',
  '080XX S MARSHFIELD AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'false',
  'true',
  '6'],
 ['08/22/2016 02:00:00 PM',
  '083XX S HERMITAGE AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '6'],
 ['04/05/2016 12:01:00 AM',
  '077XX S KEDZIE AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '8'],
 ['08/12/2016 02:00:00 PM',
  '012XX W LELAND AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'STREET',
  'false',
  'false',
  '19'],
 ['08/20/2016 07:28:00 AM',
  '087XX S MAY ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '22'],
 ['02/27/2017 04:15:00 PM',
  '053XX S CALUMET AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '2'],
 ['02/29/2016 05:45:00 PM',
  '078XX S WABASH AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '6'],
 ['12/11/2016 07:45:00 PM',
  '116XX S LOWE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['12/29/2016 06:20:00 AM',
  '097XX S CHAPPEL AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['09/14/2016 03:00:00 AM',
  '071XX N SHERIDAN RD',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '24'],
 ['05/30/2016 09:00:00 AM',
  '116XX S VINCENNES AVE',
  'OFFENSE INVOLVING CHILDREN',
  'ENDANGERING LIFE/HEALTH CHILD',
  'RESIDENCE',
  'false',
  'true',
  '22'],
 ['03/05/2016 08:00:00 PM',
  '099XX S PARNELL AVE',
  'OFFENSE INVOLVING CHILDREN',
  'OTHER OFFENSE',
  'STREET',
  'false',
  'false',
  '22'],
 ['01/07/2016 04:00:00 AM',
  '030XX W LEXINGTON ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '11'],
 ['10/01/2016 08:15:00 PM',
  '019XX S KEDZIE AVE',
  'BATTERY',
  'SIMPLE',
  'CTA STATION',
  'false',
  'false',
  '10'],
 ['06/24/2016 03:00:00 AM',
  '005XX W ENGLEWOOD AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '7'],
 ['06/26/2016 11:11:00 AM',
  '002XX W 109TH PL',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'STREET',
  'true',
  'false',
  '5'],
 ['11/29/2016 01:00:00 PM',
  '0000X S STATE ST',
  'DECEPTIVE PRACTICE',
  'ILLEGAL USE CASH CARD',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '1'],
 ['07/10/2016 03:00:00 AM',
  '029XX S WELLS ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '9'],
 ['09/29/2016 08:00:00 AM',
  '075XX N PAULINA ST',
  'THEFT',
  '$500 AND UNDER',
  'CTA PLATFORM',
  'false',
  'false',
  '24'],
 ['12/04/2016 04:50:00 PM',
  '046XX S VINCENNES AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '2'],
 ['10/07/2016 10:57:00 PM',
  '032XX W WABANSIA AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '14'],
 ['10/08/2016 11:05:00 PM',
  '018XX N KIMBALL AVE',
  'THEFT',
  'OVER $500',
  'ALLEY',
  'false',
  'false',
  '14'],
 ['12/11/2016 06:00:00 AM',
  '0000X W 26TH ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '1'],
 ['09/22/2016 04:26:00 PM',
  '050XX S BLACKSTONE AVE',
  'CRIMINAL TRESPASS',
  'TO STATE SUP LAND',
  'SCHOOL, PUBLIC, GROUNDS',
  'true',
  'false',
  '2'],
 ['10/04/2016 09:00:00 AM',
  '017XX E 72ND ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '3'],
 ['06/21/2016 10:00:00 PM',
  '008XX W HURON ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '12'],
 ['09/20/2016 09:18:00 PM',
  '083XX S STEWART AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '6'],
 ['08/04/2016 04:20:00 PM',
  '063XX N OAKLEY AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '24'],
 ['12/27/2016 05:00:00 PM',
  '119XX S INDIANA AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '5'],
 ['10/31/2016 08:30:00 AM',
  '022XX N CLEVELAND AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '18'],
 ['01/28/2017 12:12:00 AM',
  '040XX W JACKSON BLVD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['02/23/2016 07:45:00 AM',
  '062XX N WASHTENAW AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '24'],
 ['06/27/2016 11:45:00 AM',
  '036XX S LAKE PARK AVE',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '2'],
 ['11/03/2016 06:30:00 PM',
  '014XX E 69TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '3'],
 ['02/09/2017 09:00:00 AM',
  '052XX S ROCKWELL ST',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '9'],
 ['02/23/2016 06:20:00 PM',
  '010XX E 73RD ST',
  'OFFENSE INVOLVING CHILDREN',
  'CHILD ABUSE',
  'RESIDENCE',
  'true',
  'true',
  '3'],
 ['01/21/2016 10:21:00 PM',
  '086XX S MAY ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'true',
  'true',
  '6'],
 ['11/13/2016 10:32:00 PM',
  '015XX W JACKSON BLVD',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'APARTMENT',
  'false',
  'false',
  '12'],
 ['06/02/2016 05:54:00 PM',
  '027XX W MAYPOLE AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'true',
  '12'],
 ['01/04/2017 07:26:00 AM',
  '083XX S ELLIS AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '6'],
 ['05/14/2016 05:18:00 PM',
  '062XX S KEDZIE AVE',
  'ASSAULT',
  'AGGRAVATED: OTHER DANG WEAPON',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '8'],
 ['11/02/2016 03:30:00 PM',
  '071XX S CHAMPLAIN AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '3'],
 ['11/15/2016 11:00:00 AM',
  '033XX W FULTON BLVD',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['01/07/2016 02:17:00 PM',
  '072XX S EXCHANGE AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '3'],
 ['11/21/2016 09:00:00 AM',
  '082XX S ELLIS AVE',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'APARTMENT',
  'false',
  'false',
  '6'],
 ['03/26/2016 08:30:00 AM',
  '018XX N LONG AVE',
  'CRIMINAL TRESPASS',
  'TO RESIDENCE',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'true',
  '25'],
 ['08/09/2016 10:30:00 AM',
  '003XX W GRAND AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '18'],
 ['12/19/2016 03:45:00 AM',
  '061XX S PRAIRIE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '3'],
 ['06/24/2016 11:10:00 AM',
  '052XX W FERDINAND ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '15'],
 ['01/20/2016 09:15:00 PM',
  '002XX S LOTUS AVE',
  'OTHER OFFENSE',
  'LICENSE VIOLATION',
  'CONVENIENCE STORE',
  'false',
  'false',
  '15'],
 ['05/17/2016 10:35:00 AM',
  '103XX S ELIZABETH ST',
  'BATTERY',
  'PRO EMP HANDS NO/MIN INJURY',
  'SCHOOL, PUBLIC, BUILDING',
  'true',
  'false',
  '22'],
 ['06/01/2016 09:00:00 AM',
  '0000X W 40TH PL',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  '',
  'false',
  'false',
  '2'],
 ['07/02/2016 03:34:00 AM',
  '007XX N CALIFORNIA AVE',
  'OTHER OFFENSE',
  'LICENSE VIOLATION',
  'OTHER',
  'false',
  'false',
  '12'],
 ['02/15/2016 02:54:00 AM',
  '028XX W PERSHING RD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '9'],
 ['07/26/2016 06:00:00 PM',
  '043XX N NARRAGANSETT AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '16'],
 ['06/10/2016 09:00:00 PM',
  '001XX S ABERDEEN ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '12'],
 ['02/07/2016 12:00:00 PM',
  '051XX S INDIANA AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'STREET',
  'false',
  'false',
  '2'],
 ['04/28/2016 09:55:00 AM',
  '083XX S SANGAMON ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '6'],
 ['06/14/2016 04:10:00 PM',
  '013XX N ASHLAND AVE',
  'THEFT',
  'RETAIL THEFT',
  'COMMERCIAL / BUSINESS OFFICE',
  'false',
  'false',
  '14'],
 ['08/06/2016 07:00:00 AM',
  '067XX N EDGEBROOK TER',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '16'],
 ['11/15/2016 07:00:00 PM',
  '039XX N KIMBALL AVE',
  'THEFT',
  'OVER $500',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '17'],
 ['10/09/2016 09:00:00 PM',
  '020XX N KEDZIE AVE',
  'THEFT',
  'OVER $500',
  'ALLEY',
  'false',
  'false',
  '14'],
 ['05/25/2016 01:00:00 PM',
  '0000X S LA SALLE ST',
  'THEFT',
  '$500 AND UNDER',
  'SIDEWALK',
  'false',
  'false',
  '1'],
 ['05/19/2016 08:30:00 AM',
  '017XX W PRYOR AVE',
  'THEFT',
  'OVER $500',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '22'],
 ['05/30/2016 10:50:00 PM',
  '019XX S SAWYER AVE',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'STREET',
  'true',
  'false',
  '10'],
 ['04/02/2016 11:29:00 PM',
  '052XX W MONTANA ST',
  'NARCOTICS',
  'MANU/DELIVER: HEROIN (WHITE)',
  'APARTMENT',
  'true',
  'false',
  '25'],
 ['10/24/2016 02:00:00 PM',
  '083XX S HOLLAND RD',
  'THEFT',
  'OVER $500',
  'ATHLETIC CLUB',
  'false',
  'false',
  '6'],
 ['02/08/2016 12:10:00 AM',
  '002XX W WACKER DR',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'true',
  '1'],
 ['08/22/2016 12:00:00 PM',
  '004XX W BELDEN AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '18'],
 ['02/18/2017 05:22:00 AM',
  '014XX W MADISON ST',
  'PUBLIC PEACE VIOLATION',
  'BOMB THREAT',
  'OTHER',
  'false',
  'false',
  '12'],
 ['06/09/2016 10:00:00 AM',
  '079XX S SOUTH SHORE DR',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'APARTMENT',
  'false',
  'false',
  '4'],
 ['08/03/2016 09:35:00 PM',
  '059XX N TALMAN AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'APARTMENT',
  'false',
  'true',
  '20'],
 ['06/27/2016 08:30:00 PM',
  '034XX N OSCEOLA AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE',
  'false',
  'false',
  '16'],
 ['10/29/2016 09:00:00 AM',
  '019XX W GARFIELD BLVD',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '9'],
 ['02/27/2017 12:15:00 PM',
  '077XX S PHILLIPS AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['03/23/2016 03:30:00 PM',
  '100XX S VAN VLISSINGEN RD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['02/13/2017 06:30:00 AM',
  '079XX S COTTAGE GROVE AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '6'],
 ['06/28/2016 11:30:00 AM',
  '001XX S KENTON AVE',
  'PROSTITUTION',
  'SOLICIT ON PUBLIC WAY',
  'STREET',
  'true',
  'false',
  '11'],
 ['09/02/2016 09:00:00 PM',
  '056XX W ADDISON ST',
  'CRIM SEXUAL ASSAULT',
  'NON-AGGRAVATED',
  'HOSPITAL BUILDING/GROUNDS',
  'false',
  'false',
  '16'],
 ['02/02/2017 06:00:00 PM',
  '012XX S KOSTNER AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'APARTMENT',
  'false',
  'false',
  '10'],
 ['10/14/2016 08:30:00 AM',
  '031XX S LAKE SHORE DR NB',
  'THEFT',
  'OVER $500',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '2'],
 ['01/09/2016 06:14:00 AM',
  '022XX W 47TH ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '9'],
 ['12/16/2016 12:00:00 AM',
  '026XX N ELSTON AVE',
  'THEFT',
  'RETAIL THEFT',
  'DEPARTMENT STORE',
  'true',
  'false',
  '14'],
 ['02/26/2016 12:00:00 PM',
  '048XX N CHRISTIANA AVE',
  'ROBBERY',
  'ATTEMPT: ARMED-OTHER DANG WEAP',
  'SIDEWALK',
  'false',
  'false',
  '17'],
 ['05/24/2016 04:08:00 AM',
  '037XX S WALLACE ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'true',
  'false',
  '9'],
 ['11/06/2016 03:25:00 AM',
  '057XX S CARPENTER ST',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'STREET',
  'false',
  'true',
  '7'],
 ['01/17/2017 05:58:00 PM',
  '021XX W NORTH AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '14'],
 ['04/01/2016 10:54:00 AM',
  '009XX W 84TH ST',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'APARTMENT',
  'true',
  'false',
  '6'],
 ['11/17/2016 10:15:00 PM',
  '005XX W MADISON ST',
  'THEFT',
  'FROM BUILDING',
  'OTHER RAILROAD PROP / TRAIN DEPOT',
  'false',
  'false',
  '1'],
 ['04/11/2016 10:18:00 AM',
  '025XX S SPAULDING AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'ALLEY',
  'true',
  'false',
  '10'],
 ['04/02/2016 09:15:00 AM',
  '031XX W ROOSEVELT RD',
  'ASSAULT',
  'SIMPLE',
  'OTHER',
  'false',
  'false',
  '10'],
 ['02/28/2017 03:00:00 PM',
  '079XX S PRAIRIE AVE',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'RESIDENCE',
  'false',
  'false',
  '6'],
 ['08/16/2016 09:41:00 PM',
  '009XX N CROSBY ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '18'],
 ['01/21/2016 08:24:00 PM',
  '081XX S CLAREMONT AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'true',
  'false',
  '8'],
 ['05/11/2016 07:15:00 AM',
  '027XX W DEVON AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '24'],
 ['07/16/2016 06:16:00 PM',
  '015XX S HARDING AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'true',
  '10'],
 ['01/29/2016 06:00:00 PM',
  '015XX S RIDGEWAY AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '10'],
 ['02/24/2017 07:32:00 PM',
  '027XX N MARSHFIELD AVE',
  'DECEPTIVE PRACTICE',
  'AGGRAVATED FINANCIAL IDENTITY THEFT',
  'RESIDENCE',
  'false',
  'false',
  '19'],
 ['12/20/2016 03:00:00 AM',
  '045XX N PAULINA ST',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'false',
  '19'],
 ['06/03/2016 06:00:00 PM',
  '029XX N MONITOR AVE',
  'THEFT',
  'OVER $500',
  'ALLEY',
  'false',
  'false',
  '25'],
 ['01/18/2016 12:00:00 AM',
  '010XX E 42ND PL',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'RESIDENCE',
  'false',
  'false',
  '2'],
 ['07/11/2016 06:05:00 PM',
  '020XX W VAN BUREN ST',
  'CRIMINAL TRESPASS',
  'TO STATE SUP LAND',
  'CHA APARTMENT',
  'true',
  'false',
  '12'],
 ['04/03/2016 05:40:00 PM',
  '029XX W 87TH ST',
  'ASSAULT',
  'SIMPLE',
  'NURSING HOME/RETIREMENT HOME',
  'false',
  'true',
  '8'],
 ['12/27/2016 11:16:00 PM',
  '012XX N WALLER AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '25'],
 ['04/12/2016 01:00:00 AM',
  '014XX W POLK ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '12'],
 ['04/07/2016 02:30:00 PM',
  '018XX N SAYRE AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '25'],
 ['07/23/2016 11:00:00 PM',
  '100XX S CLAREMONT AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '22'],
 ['08/03/2016 04:50:00 AM',
  '047XX S LAKE PARK AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'OTHER',
  'true',
  'false',
  '2'],
 ['02/17/2017 11:15:00 AM',
  '069XX S VERNON AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '3'],
 ['03/08/2016 10:00:00 PM',
  '040XX W BELMONT AVE',
  'NARCOTICS',
  'POSS: SYNTHETIC DRUGS',
  'STREET',
  'true',
  'false',
  '25'],
 ['03/28/2016 04:15:00 PM',
  '034XX W FLOURNOY ST',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'false',
  '11'],
 ['06/28/2016 12:30:00 AM',
  '044XX W MONROE ST',
  'OTHER OFFENSE',
  'OTHER VEHICLE OFFENSE',
  'APARTMENT',
  'false',
  'false',
  '11'],
 ['03/17/2016 06:50:00 PM',
  '013XX S SAWYER AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'true',
  'true',
  '10'],
 ['03/30/2016 11:15:00 AM',
  '010XX N CENTRAL AVE',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'true',
  '15'],
 ['08/26/2016 02:00:00 PM',
  '001XX W WASHINGTON ST',
  'THEFT',
  'POCKET-PICKING',
  'CTA TRAIN',
  'false',
  'false',
  '1'],
 ['01/30/2016 02:05:00 PM',
  '035XX W JACKSON BLVD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['07/06/2016 07:50:00 PM',
  '047XX W AUGUSTA BLVD',
  'NARCOTICS',
  'POSS: COCAINE',
  'APARTMENT',
  'true',
  'false',
  '11'],
 ['02/02/2016 06:00:00 PM',
  '071XX S FRANCISCO AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'ALLEY',
  'false',
  'false',
  '8'],
 ['12/22/2016 02:00:00 AM',
  '008XX W ADDISON ST',
  'THEFT',
  'FROM BUILDING',
  'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
  'false',
  'false',
  '19'],
 ['12/01/2016 03:50:00 AM',
  '002XX S AUSTIN BLVD',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['01/30/2017 04:00:00 PM',
  '126XX S STATE ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'OTHER',
  'false',
  'false',
  '5'],
 ['12/05/2016 12:30:00 AM',
  '123XX S STATE ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '5'],
 ['09/20/2016 07:45:00 AM',
  '012XX N PARKSIDE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '25'],
 ['03/10/2016 12:15:00 PM',
  '014XX E 66TH PL',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'ALLEY',
  'false',
  'true',
  '3'],
 ['06/28/2016 03:15:00 PM',
  '002XX E 103RD ST',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '5'],
 ['04/23/2016 11:00:00 AM',
  '024XX W LEXINGTON ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'STREET',
  'false',
  'false',
  '11'],
 ['05/30/2016 12:15:00 PM',
  '021XX S CHINA PL',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'true',
  'false',
  '9'],
 ['04/16/2016 09:46:00 AM',
  '106XX S PRAIRIE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '5'],
 ['09/15/2016 06:30:00 PM',
  '034XX S COTTAGE GROVE AVE',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'false',
  '2'],
 ['09/18/2016 01:52:00 AM',
  '103XX S HARPER AVE',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'CTA GARAGE / OTHER PROPERTY',
  'true',
  'false',
  '4'],
 ['05/25/2016 09:00:00 PM',
  '053XX N MILWAUKEE AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '16'],
 ['05/25/2016 10:15:00 AM',
  '072XX S SACRAMENTO AVE',
  'ROBBERY',
  'VEHICULAR HIJACKING',
  'ALLEY',
  'true',
  'false',
  '8'],
 ['06/14/2016 07:00:00 PM',
  '001XX W JACKSON BLVD',
  'THEFT',
  'OVER $500',
  'SIDEWALK',
  'false',
  'false',
  '1'],
 ['09/21/2016 04:55:00 PM',
  '008XX S WABASH AVE',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '1'],
 ['05/05/2016 01:30:00 PM',
  '023XX N STOCKTON DR',
  'THEFT',
  'OVER $500',
  'OTHER',
  'false',
  'false',
  '18'],
 ['01/05/2016 07:50:00 PM',
  '048XX N LINCOLN AVE',
  'DECEPTIVE PRACTICE',
  'COUNTERFEITING DOCUMENT',
  'RESTAURANT',
  'false',
  'false',
  '20'],
 ['12/18/2016 09:00:00 AM',
  '020XX N HOWE ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '18'],
 ['02/16/2017 11:20:00 AM',
  '001XX N LECLAIRE AVE',
  'BATTERY',
  'SIMPLE',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '15'],
 ['05/17/2016 10:00:00 AM',
  '064XX W WABANSIA AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '25'],
 ['11/19/2016 09:10:00 AM',
  '015XX N WASHTENAW AVE',
  'THEFT',
  '$500 AND UNDER',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '14'],
 ['09/19/2016 08:21:00 PM',
  '052XX W LAKE ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'false',
  'true',
  '15'],
 ['04/24/2016 01:17:00 PM',
  '044XX N BROADWAY',
  'SEX OFFENSE',
  'PUBLIC INDECENCY',
  'OTHER',
  'true',
  'false',
  '19'],
 ['04/12/2016 05:00:00 AM',
  '109XX S AVENUE N',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '4'],
 ['03/14/2016 11:00:00 AM',
  '0000X W RANDOLPH ST',
  'THEFT',
  'FROM BUILDING',
  'ATHLETIC CLUB',
  'false',
  'false',
  '1'],
 ['01/30/2017 07:30:00 AM',
  '042XX W 76TH ST',
  'THEFT',
  'OVER $500',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '8'],
 ['07/11/2016 02:06:00 AM',
  '0000X E GRAND AVE',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '18'],
 ['01/24/2016 10:10:00 AM',
  '071XX S FAIRFIELD AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '8'],
 ['10/18/2016 03:00:00 PM',
  '002XX E LOWER RANDOLPH ST',
  'THEFT',
  'POCKET-PICKING',
  'CTA BUS',
  'false',
  'false',
  '1'],
 ['06/02/2016 03:34:00 AM',
  '056XX S DR MARTIN LUTHER KING JR DR',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '2'],
 ['10/08/2016 12:26:00 AM',
  '034XX N CLARK ST',
  'THEFT',
  'OVER $500',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '19'],
 ['11/28/2016 11:40:00 AM',
  '016XX W LAKE ST',
  'THEFT',
  'POCKET-PICKING',
  'CTA TRAIN',
  'false',
  'false',
  '12'],
 ['02/20/2016 04:00:00 PM',
  '033XX W BELDEN AVE',
  'MOTOR VEHICLE THEFT',
  'THEFT/RECOVERY: AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '14'],
 ['11/01/2016 06:30:00 PM',
  '008XX E 63RD ST',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '3'],
 ['08/28/2016 09:45:00 PM',
  '047XX W NORTH AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'true',
  'false',
  '25'],
 ['07/07/2016 12:15:00 AM',
  '072XX S DAMEN AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '7'],
 ['03/24/2016 07:30:00 PM',
  '060XX S CALUMET AVE',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '3'],
 ['09/08/2016 03:20:00 PM',
  '089XX S BRANDON AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'false',
  'true',
  '4'],
 ['09/03/2016 11:54:00 AM',
  '102XX S MICHIGAN AVE',
  'NARCOTICS',
  'POSS: CRACK',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '5'],
 ['01/30/2016 08:30:00 AM',
  '047XX N SHERIDAN RD',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'GOVERNMENT BUILDING/PROPERTY',
  'false',
  'false',
  '19'],
 ['06/11/2016 05:35:00 PM',
  '075XX S STONY ISLAND AVE',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '4'],
 ['07/24/2016 09:00:00 PM',
  '071XX S WHIPPLE ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['03/20/2016 09:00:00 PM',
  '047XX W BYRON ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '17'],
 ['08/09/2016 11:30:00 PM',
  '039XX W GLADYS AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '11'],
 ['09/02/2016 03:13:00 AM',
  '021XX S ARCHER AVE',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'RESTAURANT',
  'false',
  'false',
  '9'],
 ['11/07/2016 08:27:00 PM',
  '019XX S CENTRAL PARK AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'CTA PLATFORM',
  'false',
  'true',
  '10'],
 ['02/07/2016 05:00:00 PM',
  '029XX S DEARBORN ST',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'APARTMENT',
  'false',
  'false',
  '1'],
 ['04/06/2016 07:00:00 AM',
  '040XX N KILDARE AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '17'],
 ['11/05/2016 10:01:00 PM',
  '035XX W CERMAK RD',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'SIDEWALK',
  'true',
  'false',
  '10'],
 ['07/06/2016 12:30:00 PM',
  '064XX S JUSTINE ST',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['04/30/2016 08:45:00 AM',
  '005XX N BISHOP ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '12'],
 ['08/05/2016 01:00:00 PM',
  '049XX N BROADWAY',
  'THEFT',
  'POCKET-PICKING',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '20'],
 ['09/11/2016 02:35:00 AM',
  '091XX S COTTAGE GROVE AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'HOTEL/MOTEL',
  'false',
  'false',
  '6'],
 ['05/28/2016 02:00:00 PM',
  '024XX W LEXINGTON ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '11'],
 ['08/02/2016 02:30:00 PM',
  '015XX E 71ST ST',
  'ASSAULT',
  'AGGRAVATED: OTHER DANG WEAPON',
  'GOVERNMENT BUILDING/PROPERTY',
  'false',
  'false',
  '3'],
 ['05/17/2016 09:45:00 AM',
  '052XX W WARWICK AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'true',
  'false',
  '16'],
 ['05/25/2016 11:55:00 AM',
  '015XX E 55TH ST',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '2'],
 ['10/30/2016 12:00:00 PM',
  '081XX S RACINE AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '6'],
 ['07/10/2016 10:50:00 AM',
  '023XX N AVERS AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'true',
  'false',
  '25'],
 ['02/27/2016 04:48:00 AM',
  '034XX S HERMITAGE AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'RESIDENCE',
  'false',
  'true',
  '9'],
 ['01/13/2017 02:00:00 PM',
  '017XX N HALSTED ST',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'STREET',
  'true',
  'false',
  '18'],
 ['08/23/2016 08:55:00 AM',
  '009XX W 76TH ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '6'],
 ['05/25/2016 03:00:00 PM',
  '051XX W HARRISON ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'true',
  'true',
  '15'],
 ['10/15/2016 04:30:00 AM',
  '007XX E 133RD ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['01/08/2017 04:00:00 AM',
  '065XX S FRANCISCO AVE',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['03/15/2016 09:40:00 AM',
  '096XX S DR MARTIN LUTHER KING JR DR',
  'ROBBERY',
  'AGGRAVATED VEHICULAR HIJACKING',
  'STREET',
  'false',
  'false',
  '5'],
 ['05/26/2016 11:45:00 AM',
  '021XX E 87TH ST',
  'BATTERY',
  'SIMPLE',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '4'],
 ['07/05/2016 08:00:00 AM',
  '029XX N NEWCASTLE AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'RESIDENCE',
  'false',
  'true',
  '25'],
 ['12/26/2016 10:10:00 PM',
  '023XX W WARREN BLVD',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
  'SIDEWALK',
  'false',
  'true',
  '12'],
 ['01/06/2016 05:30:00 AM',
  '0000X S DOOR 3 ST',
  'THEFT',
  '$500 AND UNDER',
  'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
  'true',
  'false',
  '8'],
 ['05/25/2016 06:45:00 PM',
  '079XX S GREEN ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '6'],
 ['08/11/2016 05:30:00 PM',
  '028XX S HOMAN AVE',
  'THEFT',
  'OVER $500',
  'RESIDENCE',
  'false',
  'true',
  '10'],
 ['01/06/2017 04:45:00 PM',
  '001XX N STATE ST',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'DEPARTMENT STORE',
  'false',
  'false',
  '1'],
 ['11/07/2016 06:15:00 PM',
  '007XX N PULASKI RD',
  'BATTERY',
  'SIMPLE',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '11'],
 ['12/25/2016 01:15:00 PM',
  '041XX W CHICAGO AVE',
  'THEFT',
  'FROM BUILDING',
  'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
  'false',
  'false',
  '11'],
 ['10/29/2016 08:30:00 PM',
  '045XX W MONTROSE AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '17'],
 ['02/11/2017 09:28:00 AM',
  '046XX W JACKSON BLVD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['06/07/2016 07:00:00 PM',
  '081XX S DREXEL AVE',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'STREET',
  'true',
  'false',
  '6'],
 ['02/08/2016 11:50:00 AM',
  '033XX W BELMONT AVE',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'STREET',
  'false',
  'true',
  '17'],
 ['04/17/2016 10:30:00 PM',
  '064XX S PAULINA ST',
  'ROBBERY',
  'ARMED: HANDGUN',
  'STREET',
  'false',
  'false',
  '7'],
 ['08/09/2016 12:30:00 PM',
  '001XX W DIVERSEY PKWY',
  'THEFT',
  'OVER $500',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '19'],
 ['06/08/2016 10:43:00 PM',
  '028XX E 77TH ST',
  'BATTERY',
  'AGG PO HANDS NO/MIN INJURY',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['05/22/2016 02:00:00 PM',
  '102XX S WALDEN PKWY',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'false',
  '22'],
 ['06/27/2016 12:00:00 PM',
  '014XX W 72ND PL',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '7'],
 ['12/03/2016 11:53:00 AM',
  '024XX S ALBANY AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '10'],
 ['11/10/2016 09:30:00 AM',
  '014XX W 18TH ST',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'RESTAURANT',
  'false',
  'false',
  '12'],
 ['08/04/2016 09:00:00 PM',
  '089XX S ASHLAND AVE',
  'BATTERY',
  'SIMPLE',
  'CTA BUS STOP',
  'false',
  'false',
  '22'],
 ['02/18/2016 07:15:00 PM',
  '013XX W 76TH ST',
  'NARCOTICS',
  'POSS: CANNABIS MORE THAN 30GMS',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '6'],
 ['02/05/2017 06:10:00 AM',
  '031XX S HAMLIN AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '10'],
 ['01/16/2016 01:00:00 PM',
  '007XX N OGDEN AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '12'],
 ['01/03/2017 09:30:00 PM',
  '011XX N MASSASOIT AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '15'],
 ['10/10/2016 03:27:00 AM',
  '063XX N KENMORE AVE',
  'BATTERY',
  'SIMPLE',
  'ALLEY',
  'false',
  'false',
  '24'],
 ['02/01/2016 09:00:00 AM',
  '028XX W CERMAK RD',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'APARTMENT',
  'false',
  'false',
  '10'],
 ['02/13/2016 09:40:00 PM',
  '097XX S UNION AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'true',
  '22'],
 ['09/06/2016 09:30:00 AM',
  '036XX N ELSTON AVE',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '17'],
 ['01/04/2017 03:15:00 PM',
  '008XX N KEDZIE AVE',
  'BATTERY',
  'SIMPLE',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '11'],
 ['01/23/2016 08:12:00 PM',
  '071XX S DR MARTIN LUTHER KING JR DR',
  'THEFT',
  'FROM BUILDING',
  'GAS STATION',
  'false',
  'false',
  '3'],
 ['12/14/2016 05:50:00 PM',
  '002XX W GARFIELD BLVD',
  'THEFT',
  'PURSE-SNATCHING',
  'CTA PLATFORM',
  'false',
  'false',
  '9'],
 ['09/07/2016 12:20:00 PM',
  '031XX S LITUANICA AVE',
  'ASSAULT',
  'SIMPLE',
  'CHA PARKING LOT/GROUNDS',
  'false',
  'false',
  '9'],
 ['11/12/2016 07:00:00 PM',
  '073XX N RIDGE BLVD',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'true',
  '24'],
 ['10/19/2016 02:02:00 PM',
  '098XX S HALSTED ST',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'STREET',
  'true',
  'false',
  '22'],
 ['01/31/2017 03:30:00 PM',
  '077XX S BURNHAM AVE',
  'ASSAULT',
  'AGG PRO.EMP: OTHER DANG WEAPON',
  'SCHOOL, PUBLIC, GROUNDS',
  'true',
  'false',
  '4'],
 ['08/03/2016 01:50:00 AM',
  '031XX W LEXINGTON ST',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['01/01/2016 09:00:00 AM',
  '022XX N KOSTNER AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '25'],
 ['08/16/2016 12:00:00 PM',
  '050XX N WINCHESTER AVE',
  'THEFT',
  'FROM BUILDING',
  'APARTMENT',
  'false',
  'false',
  '20'],
 ['01/25/2016 08:25:00 AM',
  '068XX S NORMAL BLVD',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'APARTMENT',
  'true',
  'true',
  '7'],
 ['10/11/2016 11:26:00 AM',
  '003XX N CENTRAL AVE',
  'ASSAULT',
  'SIMPLE',
  'OTHER',
  'false',
  'false',
  '15'],
 ['06/09/2016 06:35:00 PM',
  '022XX W 23RD PL',
  'BATTERY',
  'SIMPLE',
  'ALLEY',
  'true',
  'false',
  '10'],
 ['01/30/2016 07:30:00 PM',
  '023XX N KEDVALE AVE',
  'MOTOR VEHICLE THEFT',
  'ATT: AUTOMOBILE',
  'STREET',
  'true',
  'false',
  '25'],
 ['11/13/2016 08:20:00 AM',
  '008XX S INDEPENDENCE BLVD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['06/17/2016 07:00:00 PM',
  '009XX N HOMAN AVE',
  'NARCOTICS',
  'MANU/DELIVER: HEROIN (WHITE)',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['05/10/2016 06:30:00 AM',
  '068XX S PULASKI RD',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '8'],
 ['02/02/2017 01:20:00 PM',
  '073XX N WESTERN AVE',
  'THEFT',
  'OVER $500',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '24'],
 ['09/01/2016 03:00:00 PM',
  '079XX S MANISTEE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '4'],
 ['02/12/2016 05:00:00 PM',
  '031XX W 64TH ST',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'STREET',
  'false',
  'false',
  '8'],
 ['01/04/2016 06:15:00 PM',
  '012XX N STATE PKWY',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '18'],
 ['08/28/2016 09:00:00 AM',
  '068XX S MAPLEWOOD AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '8'],
 ['05/15/2016 12:00:00 PM',
  '073XX S DREXEL AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '3'],
 ['11/23/2016 05:30:00 PM',
  '048XX W DIVERSEY AVE',
  'ROBBERY',
  'ATTEMPT: ARMED-KNIFE/CUT INSTR',
  'STREET',
  'false',
  'false',
  '25'],
 ['04/29/2016 04:00:00 PM',
  '006XX N HOYNE AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '12'],
 ['08/15/2016 08:23:00 PM',
  '089XX S EAST END AVE',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['06/12/2016 10:30:00 AM',
  '027XX W HARRISON ST',
  'ASSAULT',
  'SIMPLE',
  'OTHER',
  'false',
  'false',
  '11'],
 ['08/09/2016 07:00:00 PM',
  '042XX W MELROSE ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '17'],
 ['07/02/2016 01:20:00 AM',
  '072XX S PHILLIPS AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'STREET',
  'false',
  'false',
  '3'],
 ['09/21/2016 09:45:00 PM',
  '007XX E GRAND AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESTAURANT',
  'false',
  'true',
  '18'],
 ['10/16/2016 04:15:00 PM',
  '008XX N MICHIGAN AVE',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'true',
  'false',
  '18'],
 ['01/20/2017 09:30:00 PM',
  '049XX S PULASKI RD',
  'THEFT',
  'OVER $500',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '8'],
 ['03/14/2016 10:26:00 PM',
  '010XX E 79TH ST',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'STREET',
  'true',
  'false',
  '6'],
 ['01/01/2017 06:10:00 AM',
  '060XX S KENNETH AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['05/02/2016 11:15:00 PM',
  '034XX W CERMAK RD',
  'OTHER OFFENSE',
  'PAROLE VIOLATION',
  'STREET',
  'true',
  'false',
  '10'],
 ['03/11/2016 12:00:00 AM',
  '010XX N DAMEN AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE',
  'false',
  'false',
  '12'],
 ['10/08/2016 04:15:00 PM',
  '052XX W FULTON ST',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '15'],
 ['02/14/2017 09:24:00 AM',
  '056XX S RICHMOND ST',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '8'],
 ['01/15/2017 09:30:00 AM',
  '011XX N RIDGEWAY AVE',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'ALLEY',
  'true',
  'false',
  '11'],
 ['06/25/2016 11:00:00 AM',
  '023XX W CERMAK RD',
  'THEFT',
  '$500 AND UNDER',
  'RESTAURANT',
  'false',
  'false',
  '10'],
 ['01/06/2017 01:30:00 PM',
  '060XX S HARPER AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '3'],
 ['06/16/2016 10:30:00 AM',
  '036XX W 47TH ST',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '8'],
 ['02/21/2016 12:00:00 PM',
  '006XX W PATTERSON AVE',
  'DECEPTIVE PRACTICE',
  'ATTEMPT - FINANCIAL IDENTITY THEFT',
  'RESIDENCE',
  'false',
  'false',
  '19'],
 ['11/19/2016 08:00:00 PM',
  '014XX E 68TH ST',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY',
  'RESIDENCE',
  'false',
  'true',
  '3'],
 ['06/06/2016 10:05:00 PM',
  '055XX S HONORE ST',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'true',
  'false',
  '7'],
 ['04/21/2016 08:50:00 AM',
  '046XX N SPRINGFIELD AVE',
  'OTHER OFFENSE',
  'FALSE/STOLEN/ALTERED TRP',
  'STREET',
  'false',
  'false',
  '17'],
 ['03/01/2017 01:30:00 PM',
  '037XX W FLOURNOY ST',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '11'],
 ['09/24/2016 09:20:00 AM',
  '017XX W ELLEN ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'DRIVEWAY - RESIDENTIAL',
  'false',
  'false',
  '14'],
 ['03/31/2016 03:45:00 AM',
  '027XX W ROOSEVELT RD',
  'SEX OFFENSE',
  'CRIMINAL SEXUAL ABUSE',
  'OTHER',
  'false',
  'false',
  '11'],
 ['05/12/2016 08:46:00 PM',
  '045XX S HONORE ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '9'],
 ['08/09/2016 07:45:00 PM',
  '051XX W NORTH AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '25'],
 ['01/01/2016 01:30:00 AM',
  '076XX N SHERIDAN RD',
  'OFFENSE INVOLVING CHILDREN',
  'OTHER OFFENSE',
  'APARTMENT',
  'false',
  'true',
  '24'],
 ['07/18/2016 03:24:00 PM',
  '011XX S CLARK ST',
  'THEFT',
  'RETAIL THEFT',
  'DEPARTMENT STORE',
  'true',
  'false',
  '1'],
 ['03/04/2016 09:00:00 AM',
  '052XX W ALTGELD ST',
  'SEX OFFENSE',
  'CRIMINAL SEXUAL ABUSE',
  'APARTMENT',
  'false',
  'false',
  '25'],
 ['02/13/2016 12:00:00 PM',
  '007XX N ST LOUIS AVE',
  'NARCOTICS',
  'MANU/DEL:CANNABIS 10GM OR LESS',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['01/29/2016 03:20:00 PM',
  '029XX S WABASH AVE',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'SCHOOL, PUBLIC, GROUNDS',
  'true',
  'false',
  '1'],
 ['05/24/2016 10:40:00 PM',
  '006XX E 62ND ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['08/26/2016 05:00:00 AM',
  '073XX S EAST END AVE',
  'CRIM SEXUAL ASSAULT',
  'NON-AGGRAVATED',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['01/05/2017 07:07:00 PM',
  '015XX N FREMONT ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '18'],
 ['09/20/2016 06:55:00 PM',
  '010XX N LEAMINGTON AVE',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['12/30/2016 10:53:00 AM',
  '016XX N PULASKI RD',
  'THEFT',
  'RETAIL THEFT',
  'CONVENIENCE STORE',
  'true',
  'false',
  '25'],
 ['12/10/2016 12:36:00 PM',
  '002XX N PULASKI RD',
  'ROBBERY',
  'AGGRAVATED',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '11'],
 ['04/26/2016 12:35:00 AM',
  '058XX S LAFLIN ST',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'STREET',
  'false',
  'false',
  '7'],
 ['03/06/2016 07:00:00 PM',
  '078XX S PAULINA ST',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'RESIDENCE',
  'false',
  'true',
  '6'],
 ['02/23/2016 03:55:00 PM',
  '010XX W 59TH ST',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'true',
  'false',
  '7'],
 ['08/07/2016 10:40:00 PM',
  '031XX W MARQUETTE RD',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '8'],
 ['08/27/2016 02:10:00 PM',
  '016XX W 59TH ST',
  'THEFT',
  'RETAIL THEFT',
  'SMALL RETAIL STORE',
  'true',
  'false',
  '7'],
 ['03/24/2016 12:15:00 PM',
  '005XX N ST LOUIS AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '11'],
 ['10/06/2016 09:00:00 AM',
  '048XX S THROOP ST',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'RESIDENCE',
  'false',
  'true',
  '9'],
 ['07/22/2016 01:56:00 PM',
  '001XX W 35TH ST',
  'THEFT',
  '$500 AND UNDER',
  'CTA TRAIN',
  'true',
  'false',
  '9'],
 ['03/28/2016 12:55:00 PM',
  '091XX S EUCLID AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'SIDEWALK',
  'true',
  'false',
  '4'],
 ['07/13/2016 06:00:00 PM',
  '113XX S DR MARTIN LUTHER KING JR DR',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '5'],
 ['02/26/2017 08:45:00 PM',
  '019XX W MADISON ST',
  'THEFT',
  'FROM BUILDING',
  'SPORTS ARENA/STADIUM',
  'false',
  'false',
  '12'],
 ['02/26/2016 05:45:00 PM',
  '038XX W AUGUSTA BLVD',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '11'],
 ['12/23/2016 11:40:00 AM',
  '011XX S CANAL ST',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'DEPARTMENT STORE',
  'true',
  'false',
  '1'],
 ['07/05/2016 05:40:00 PM',
  '095XX S EXCHANGE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['12/29/2016 01:00:00 PM',
  '029XX N COMMONWEALTH AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '19'],
 ['12/06/2016 03:23:00 PM',
  '059XX N KIMBALL AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '17'],
 ['05/14/2016 11:00:00 AM',
  '0000X E CHICAGO AVE',
  'DECEPTIVE PRACTICE',
  'COUNTERFEIT CHECK',
  'CURRENCY EXCHANGE',
  'false',
  'false',
  '18'],
 ['10/24/2016 11:40:00 AM',
  '111XX S STATE ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '5'],
 ['05/14/2016 02:00:00 AM',
  '001XX E 60TH ST',
  'BATTERY',
  'SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'false',
  '2'],
 ['12/19/2016 12:30:00 PM',
  '087XX S ABERDEEN ST',
  'BATTERY',
  'SIMPLE',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '22'],
 ['04/30/2016 12:00:00 AM',
  '066XX S WHIPPLE ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '8'],
 ['11/21/2016 03:50:00 PM',
  '015XX W GARFIELD BLVD',
  'BATTERY',
  'PRO EMP HANDS NO/MIN INJURY',
  'CTA BUS',
  'false',
  'false',
  '9'],
 ['07/04/2016 02:00:00 AM',
  '015XX S MICHIGAN AVE',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '1'],
 ['02/21/2017 04:00:00 PM',
  '008XX S MICHIGAN AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '1'],
 ['04/21/2016 11:00:00 AM',
  '064XX S WINCHESTER AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'true',
  'true',
  '7'],
 ['01/05/2017 10:22:00 PM',
  '008XX N LEAMINGTON AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'VEHICLE NON-COMMERCIAL',
  'true',
  'true',
  '15'],
 ['12/20/2016 09:00:00 PM',
  '044XX W VAN BUREN ST',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'STREET',
  'false',
  'false',
  '11'],
 ['01/14/2017 01:35:00 AM',
  '048XX N CENTRAL AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'APARTMENT',
  'false',
  'false',
  '16'],
 ['05/21/2016 10:52:00 AM',
  '080XX S INGLESIDE AVE',
  'THEFT',
  '$500 AND UNDER',
  'ALLEY',
  'false',
  'false',
  '6'],
 ['07/17/2016 06:00:00 AM',
  '024XX N BERNARD ST',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE',
  'false',
  'false',
  '14'],
 ['11/01/2016 07:30:00 AM',
  '084XX S BURLEY AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'APARTMENT',
  'false',
  'false',
  '4'],
 ['06/16/2016 10:00:00 AM',
  '123XX S YALE AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '5'],
 ['01/21/2016 11:00:00 PM',
  '065XX S MINERVA AVE',
  'ASSAULT',
  'AGGRAVATED:KNIFE/CUTTING INSTR',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['08/13/2016 05:30:00 PM',
  '030XX S CALIFORNIA BLVD',
  'DECEPTIVE PRACTICE',
  'ILLEGAL USE CASH CARD',
  'STREET',
  'false',
  'false',
  '10'],
 ['12/22/2016 01:07:00 PM',
  '006XX N LAWNDALE AVE',
  'BATTERY',
  'PRO EMP HANDS NO/MIN INJURY',
  'SCHOOL, PUBLIC, BUILDING',
  'true',
  'false',
  '11'],
 ['01/26/2016 03:15:00 PM',
  '094XX S PRAIRIE AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '6'],
 ['01/12/2016 09:30:00 PM',
  '031XX N ASHLAND AVE',
  'THEFT',
  'FROM BUILDING',
  'ATHLETIC CLUB',
  'false',
  'false',
  '19'],
 ['12/24/2016 04:00:00 PM',
  '069XX S TALMAN AVE',
  'BATTERY',
  'AGGRAVATED:KNIFE/CUTTING INSTR',
  'RESIDENCE',
  'true',
  'false',
  '8'],
 ['02/18/2016 09:15:00 AM',
  '014XX N MILWAUKEE AVE',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '14'],
 ['04/02/2016 08:32:00 AM',
  '069XX S VERNON AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '3'],
 ['12/24/2016 04:00:00 PM',
  '004XX N MICHIGAN AVE',
  'ASSAULT',
  'SIMPLE',
  'CONVENIENCE STORE',
  'true',
  'false',
  '18'],
 ['01/12/2017 08:45:00 AM',
  '020XX W FERDINAND ST',
  'BATTERY',
  'SIMPLE',
  'OTHER',
  'false',
  'false',
  '12'],
 ['03/02/2016 06:20:00 PM',
  '009XX N MICHIGAN AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'OTHER',
  'false',
  'false',
  '18'],
 ['02/12/2017 06:45:00 AM',
  '108XX S AVENUE L',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '4'],
 ['11/09/2016 07:15:00 PM',
  '006XX N CLARK ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '18'],
 ['08/15/2016 01:45:00 PM',
  '002XX N PINE AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'false',
  '15'],
 ['02/26/2016 07:24:00 AM',
  '022XX N KILDARE AVE',
  'MOTOR VEHICLE THEFT',
  'THEFT/RECOVERY: AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '25'],
 ['12/05/2016 07:55:00 PM',
  '004XX W 76TH ST',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'STREET',
  'false',
  'false',
  '6'],
 ['01/06/2017 03:15:00 AM',
  '082XX S VERNON AVE',
  'ASSAULT',
  'AGGRAVATED:KNIFE/CUTTING INSTR',
  'APARTMENT',
  'false',
  'false',
  '6'],
 ['01/13/2017 08:00:00 AM',
  '073XX S PEORIA ST',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '7'],
 ['11/17/2016 09:00:00 PM',
  '014XX S TRIPP AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '10'],
 ['06/21/2016 10:00:00 AM',
  '034XX W FRANKLIN BLVD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '11'],
 ['01/07/2017 12:23:00 AM',
  '072XX S DOBSON AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '3'],
 ['08/18/2016 04:00:00 PM',
  '006XX W ARLINGTON PL',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '19'],
 ['07/09/2016 02:00:00 PM',
  '083XX S SANGAMON ST',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '6'],
 ['07/29/2016 09:00:00 AM',
  '026XX W ESTES AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '24'],
 ['02/25/2017 10:00:00 PM',
  '060XX S MOZART ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '8'],
 ['08/27/2016 02:00:00 AM',
  '012XX S CALIFORNIA BLVD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'PARK PROPERTY',
  'false',
  'true',
  '10'],
 ['05/22/2016 08:02:00 PM',
  '004XX S WESTERN AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'CTA TRAIN',
  'false',
  'false',
  '11'],
 ['01/22/2017 10:00:00 PM',
  '057XX S KENTON AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '8'],
 ['04/20/2016 12:44:00 PM',
  '014XX N MAYFIELD AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'true',
  'true',
  '25'],
 ['05/01/2016 12:00:00 PM',
  '072XX S CAMPBELL AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['07/29/2016 03:45:00 PM',
  '003XX E RANDOLPH ST',
  'THEFT',
  'POCKET-PICKING',
  'PARK PROPERTY',
  'false',
  'false',
  '1'],
 ['09/08/2016 03:15:00 PM',
  '085XX S MACKINAW AVE',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['03/31/2016 10:30:00 PM',
  '053XX N LINCOLN AVE',
  'THEFT',
  'OVER $500',
  'BAR OR TAVERN',
  'false',
  'false',
  '20'],
 ['08/22/2016 06:00:00 PM',
  '019XX W CHICAGO AVE',
  'SEX OFFENSE',
  'CRIMINAL SEXUAL ABUSE',
  'APARTMENT',
  'false',
  'false',
  '12'],
 ['11/28/2016 07:56:00 AM',
  '035XX W 62ND PL',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '8'],
 ['06/29/2016 04:00:00 PM',
  '033XX W 53RD ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '8'],
 ['01/13/2016 02:30:00 PM',
  '013XX N STATE PKWY',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '18'],
 ['03/23/2016 12:14:00 PM',
  '085XX S COTTAGE GROVE AVE',
  'THEFT',
  'RETAIL THEFT',
  'DEPARTMENT STORE',
  'false',
  'false',
  '6'],
 ['03/26/2016 10:30:00 PM',
  '027XX N MONITOR AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '25'],
 ['03/13/2016 12:15:00 AM',
  '018XX W JACKSON BLVD',
  'ARSON',
  'AGGRAVATED',
  'APARTMENT',
  'false',
  'false',
  '12'],
 ['02/20/2016 10:14:00 PM',
  '039XX W MADISON ST',
  'CRIMINAL TRESPASS',
  'TO LAND',
  'TAVERN/LIQUOR STORE',
  'true',
  'false',
  '11'],
 ['05/21/2016 11:00:00 AM',
  '0000X E CONGRESS PKWY',
  'THEFT',
  'FROM BUILDING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['10/01/2016 07:10:00 PM',
  '052XX W GEORGE ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '25'],
 ['10/16/2016 08:00:00 AM',
  '007XX N PULASKI RD',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'OTHER',
  'false',
  'false',
  '11'],
 ['09/30/2016 01:00:00 PM',
  '014XX N KEELER AVE',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '25'],
 ['02/19/2017 11:55:00 AM',
  '038XX W MAYPOLE AVE',
  'NARCOTICS',
  'MANU/DELIVER: HEROIN (WHITE)',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['12/20/2016 07:35:00 PM',
  '008XX W BUCKINGHAM PL',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '19'],
 ['02/13/2016 10:33:00 PM',
  '045XX W MAYPOLE AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'STREET',
  'true',
  'false',
  '11'],
 ['04/08/2016 07:07:00 PM',
  '006XX W HARRISON ST',
  'DECEPTIVE PRACTICE',
  'THEFT OF LOST/MISLAID PROP',
  'OTHER COMMERCIAL TRANSPORTATION',
  'true',
  'true',
  '1'],
 ['01/12/2016 07:00:00 PM',
  '012XX S SAWYER AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'true',
  'false',
  '10'],
 ['05/19/2016 08:37:00 AM',
  '074XX S KENWOOD AVE',
  'ROBBERY',
  'ARMED:KNIFE/CUTTING INSTRUMENT',
  'OTHER',
  'false',
  'false',
  '3'],
 ['02/17/2017 07:58:00 PM',
  '008XX E 90TH PL',
  'OFFENSE INVOLVING CHILDREN',
  'OTHER OFFENSE',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '6'],
 ['12/25/2016 02:45:00 AM',
  '116XX S WALLACE ST',
  'OTHER OFFENSE',
  'OTHER VEHICLE OFFENSE',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['12/13/2016 08:30:00 PM',
  '008XX E 76TH ST',
  'NARCOTICS',
  'POSSESSION OF DRUG EQUIPMENT',
  'STREET',
  'true',
  'false',
  '6'],
 ['11/08/2016 08:40:00 PM',
  '055XX S KEDZIE AVE',
  'THEFT',
  '$500 AND UNDER',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '8'],
 ['12/07/2016 08:00:00 PM',
  '080XX S UNIVERSITY AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '4'],
 ['01/27/2016 10:30:00 PM',
  '020XX W 70TH PL',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '7'],
 ['11/23/2016 09:30:00 AM',
  '013XX E 47TH ST',
  'ASSAULT',
  'SIMPLE',
  'CONVENIENCE STORE',
  'true',
  'false',
  '2'],
 ['02/11/2016 12:00:00 PM',
  '103XX S HOMAN AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '22'],
 ['08/12/2016 04:00:00 PM',
  '085XX S MUSKEGON AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'true',
  '4'],
 ['09/20/2016 01:05:00 AM',
  '049XX S WESTERN AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '9'],
 ['11/07/2016 12:01:00 AM',
  '087XX S STONY ISLAND AVE',
  'THEFT',
  'RETAIL THEFT',
  'DRUG STORE',
  'false',
  'false',
  '4'],
 ['03/01/2017 07:00:00 PM',
  '001XX N CLARK ST',
  'THEFT',
  'FROM BUILDING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['02/22/2017 11:40:00 PM',
  '078XX S JEFFERY BLVD',
  'BATTERY',
  'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
  'APARTMENT',
  'false',
  'false',
  '4'],
 ['10/11/2016 08:35:00 AM',
  '028XX W 59TH ST',
  'THEFT',
  '$500 AND UNDER',
  'GAS STATION',
  'false',
  'false',
  '8'],
 ['09/11/2016 09:00:00 PM',
  '022XX E 102ND ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '4'],
 ['07/10/2016 01:10:00 AM',
  '095XX S PERRY AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'RESIDENCE',
  'false',
  'false',
  '5'],
 ['06/05/2016 11:38:00 PM',
  '073XX S PEORIA ST',
  'BATTERY',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['12/13/2016 02:30:00 PM',
  '011XX S CANAL ST',
  'THEFT',
  'POCKET-PICKING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['12/28/2016 03:00:00 PM',
  '015XX W 46TH ST',
  'OTHER OFFENSE',
  'OTHER VEHICLE OFFENSE',
  'OTHER',
  'false',
  'false',
  '9'],
 ['06/04/2016 09:13:00 AM',
  '039XX W GRENSHAW ST',
  'PUBLIC PEACE VIOLATION',
  'OTHER VIOLATION',
  'OTHER',
  'false',
  'false',
  '11'],
 ['03/06/2016 07:00:00 PM',
  '050XX N TRIPP AVE',
  'THEFT',
  'OVER $500',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '17'],
 ['05/30/2016 08:00:00 PM',
  '047XX N MARIA CT',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '16'],
 ['06/07/2016 06:00:00 PM',
  '053XX S SAWYER AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '8'],
 ['04/14/2016 07:58:00 AM',
  '006XX W OHARE ST',
  'BATTERY',
  'SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'true',
  'false',
  '16'],
 ['10/15/2016 08:33:00 AM',
  '022XX W CORNELIA AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '19'],
 ['04/21/2016 08:00:00 PM',
  '084XX S DREXEL AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'true',
  '6'],
 ['08/07/2016 02:50:00 PM',
  '014XX W 115TH ST',
  'BATTERY',
  'SIMPLE',
  'CONVENIENCE STORE',
  'false',
  'false',
  '22'],
 ['01/01/2017 08:10:00 AM',
  '028XX W 86TH PL',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'true',
  '8'],
 ['01/21/2016 01:45:00 AM',
  '095XX S CONSTANCE AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'true',
  '4'],
 ['07/17/2016 04:42:00 AM',
  '018XX W BERENICE AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'OTHER',
  'false',
  'false',
  '19'],
 ['04/25/2016 07:43:00 PM',
  '021XX S SPRINGFIELD AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'true',
  'true',
  '10'],
 ['03/02/2016 02:35:00 PM',
  '056XX S BISHOP ST',
  'NARCOTICS',
  'MANU/DEL:CANNABIS 10GM OR LESS',
  'SIDEWALK',
  'true',
  'false',
  '7'],
 ['08/03/2016 03:30:00 PM',
  '026XX N MILWAUKEE AVE',
  'SEX OFFENSE',
  'PUBLIC INDECENCY',
  'CTA TRAIN',
  'false',
  'false',
  '14'],
 ['03/22/2016 02:00:00 PM',
  '005XX W LAKE ST',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'CTA GARAGE / OTHER PROPERTY',
  'false',
  'false',
  '1'],
 ['07/16/2016 12:45:00 PM',
  '002XX E ERIE ST',
  'THEFT',
  '$500 AND UNDER',
  'SIDEWALK',
  'false',
  'false',
  '18'],
 ['08/13/2016 02:45:00 AM',
  '012XX S HALSTED ST',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'VEHICLE - OTHER RIDE SERVICE',
  'false',
  'false',
  '12'],
 ['05/18/2016 02:00:00 AM',
  '029XX N LOWELL AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '25'],
 ['05/12/2016 01:00:00 PM',
  '057XX W 64TH ST',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '8'],
 ['07/20/2016 10:00:00 AM',
  '013XX S FEDERAL ST',
  'THEFT',
  'OVER $500',
  'RESIDENCE',
  'false',
  'false',
  '1'],
 ['07/26/2016 02:40:00 AM',
  '019XX N RICHMOND ST',
  'CRIMINAL TRESPASS',
  'TO RESIDENCE',
  'RESIDENCE PORCH/HALLWAY',
  'true',
  'true',
  '14'],
 ['08/24/2016 12:55:00 AM',
  '054XX S RACINE AVE',
  'BATTERY',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'false',
  '9'],
 ['01/09/2016 11:00:00 PM',
  '075XX W FOREST PRESERVE AVE',
  'MOTOR VEHICLE THEFT',
  'ATT: AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '16'],
 ['01/03/2017 03:38:00 PM',
  '040XX W WABANSIA AVE',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'SIDEWALK',
  'true',
  'false',
  '25'],
 ['09/04/2016 07:00:00 PM',
  '061XX S PULASKI RD',
  'THEFT',
  '$500 AND UNDER',
  'RESTAURANT',
  'false',
  'false',
  '8'],
 ['01/02/2016 09:00:00 AM',
  '024XX W 34TH PL',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '9'],
 ['07/30/2016 03:00:00 PM',
  '010XX N RUSH ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '18'],
 ['08/31/2016 09:40:00 PM',
  '076XX S SOUTH SHORE DR',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['09/03/2016 12:05:00 AM',
  '003XX N BELL AVE',
  'BATTERY',
  'SIMPLE',
  'OTHER',
  'false',
  'false',
  '12'],
 ['04/21/2016 08:00:00 PM',
  '055XX W CONGRESS PKWY',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'APARTMENT',
  'false',
  'false',
  '15'],
 ['04/24/2016 08:30:00 PM',
  '065XX S DR MARTIN LUTHER KING JR DR',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'OTHER',
  'false',
  'false',
  '3'],
 ['06/12/2016 11:37:00 PM',
  '047XX W MADISON ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'CONVENIENCE STORE',
  'false',
  'false',
  '11'],
 ['11/12/2016 12:00:00 PM',
  '022XX N CANNON DR',
  'THEFT',
  'OVER $500',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '18'],
 ['02/16/2016 02:10:00 PM',
  '082XX S RICHMOND ST',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '8'],
 ['05/18/2016 12:00:00 PM',
  '015XX W BERTEAU AVE',
  'DECEPTIVE PRACTICE',
  'ATTEMPT - FINANCIAL IDENTITY THEFT',
  'APARTMENT',
  'false',
  'false',
  '19'],
 ['12/19/2016 06:45:00 AM',
  '072XX S EAST END AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '3'],
 ['12/23/2016 06:00:00 PM',
  '0000X W 79TH ST',
  'CRIMINAL TRESPASS',
  'TO STATE SUP LAND',
  'CTA PLATFORM',
  'true',
  'false',
  '6'],
 ['06/19/2016 04:00:00 PM',
  '041XX S ALBANY AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '9'],
 ['07/02/2016 10:30:00 AM',
  '011XX W WASHBURNE AVE',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'APARTMENT',
  'false',
  'true',
  '12'],
 ['03/28/2016 01:38:00 AM',
  '084XX S EXCHANGE AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'true',
  'false',
  '4'],
 ['08/29/2016 01:00:00 AM',
  '046XX N MARINE DR',
  'THEFT',
  'FROM BUILDING',
  'HOSPITAL BUILDING/GROUNDS',
  'false',
  'false',
  '19'],
 ['01/02/2017 05:00:00 PM',
  '014XX W 47TH ST',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '9'],
 ['07/07/2016 02:00:00 PM',
  '043XX N SHERIDAN RD',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '19'],
 ['05/14/2016 07:00:00 PM',
  '086XX S STONY ISLAND AVE',
  'THEFT',
  'OVER $500',
  'GAS STATION',
  'false',
  'false',
  '4'],
 ['03/18/2016 02:30:00 AM',
  '012XX S WABASH AVE',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '1'],
 ['08/19/2016 03:39:00 PM',
  '051XX W 55TH ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'OTHER',
  'false',
  'false',
  '8'],
 ['08/19/2016 02:00:00 AM',
  '039XX W ARTHINGTON ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '11'],
 ['07/06/2016 02:30:00 AM',
  '013XX W HURON ST',
  'CRIMINAL TRESPASS',
  'TO VEHICLE',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '12'],
 ['09/30/2016 03:00:00 PM',
  '024XX S CHRISTIANA AVE',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'STREET',
  'false',
  'false',
  '10'],
 ['02/06/2017 03:00:00 PM',
  '021XX W 95TH ST',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESTAURANT',
  'false',
  'false',
  '22'],
 ['07/28/2016 11:17:00 AM',
  '040XX N ALBANY AVE',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'APARTMENT',
  'false',
  'false',
  '17'],
 ['01/29/2017 07:30:00 PM',
  '050XX N NORDICA AVE',
  'THEFT',
  '$500 AND UNDER',
  'DRIVEWAY - RESIDENTIAL',
  'false',
  'false',
  '16'],
 ['08/12/2016 10:15:00 AM',
  '049XX N MILWAUKEE AVE',
  'NARCOTICS',
  'POSS: HEROIN(WHITE)',
  'CTA STATION',
  'true',
  'false',
  '16'],
 ['08/09/2016 11:50:00 AM',
  '035XX N HALSTED ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  '',
  'false',
  'false',
  '19'],
 ['03/01/2017 02:06:00 PM',
  '004XX S KOSTNER AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT $300 AND UNDER',
  'GAS STATION',
  'false',
  'false',
  '11'],
 ['03/31/2016 10:00:00 AM',
  '006XX E 85TH ST',
  'BATTERY',
  'PRO EMP HANDS NO/MIN INJURY',
  'SCHOOL, PUBLIC, BUILDING',
  'false',
  'false',
  '6'],
 ['10/15/2016 12:00:00 AM',
  '066XX S MAPLEWOOD AVE',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'STREET',
  'false',
  'false',
  '8'],
 ['08/14/2016 04:30:00 AM',
  '007XX S ASHLAND AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'true',
  'true',
  '12'],
 ['01/31/2017 12:00:00 PM',
  '015XX N KILDARE AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT $300 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '25'],
 ['12/01/2016 11:00:00 AM',
  '068XX S THROOP ST',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '7'],
 ['01/16/2016 07:40:00 AM',
  '116XX S UNION AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '5'],
 ['11/20/2016 08:00:00 AM',
  '049XX N LEAVITT ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '20'],
 ['10/16/2016 11:50:00 PM',
  '011XX W 18TH PL',
  'ASSAULT',
  'SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '12'],
 ['09/08/2016 04:35:00 PM',
  '044XX W FIFTH AVE',
  'BATTERY',
  'SIMPLE',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['08/09/2016 09:30:00 AM',
  '087XX S ASHLAND AVE',
  'THEFT',
  'OVER $500',
  'COMMERCIAL / BUSINESS OFFICE',
  'false',
  'false',
  '22'],
 ['09/10/2016 02:00:00 AM',
  '072XX S ROCKWELL ST',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'true',
  '8'],
 ['01/26/2016 02:30:00 AM',
  '024XX N HALSTED ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'true',
  '19'],
 ['11/25/2016 12:00:00 PM',
  '082XX S SOUTH SHORE DR',
  'THEFT',
  'OVER $500',
  'APARTMENT',
  'false',
  'false',
  '4'],
 ['04/24/2016 08:00:00 PM',
  '007XX N AVERS AVE',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'WAREHOUSE',
  'false',
  'false',
  '11'],
 ['10/04/2016 06:45:00 PM',
  '050XX W WASHINGTON BLVD',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'true',
  '15'],
 ['05/18/2016 03:45:00 PM',
  '073XX S JEFFERY BLVD',
  'ASSAULT',
  'SIMPLE',
  'SCHOOL, PUBLIC, GROUNDS',
  'false',
  'false',
  '3'],
 ['01/05/2016 02:00:00 PM',
  '002XX W 104TH PL',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '5'],
 ['09/29/2016 10:56:00 AM',
  '079XX S KINGSTON AVE',
  'ASSAULT',
  'AGGRAVATED: HANDGUN',
  'APARTMENT',
  'true',
  'true',
  '4'],
 ['05/22/2016 01:45:00 PM',
  '078XX S EXCHANGE AVE',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '4'],
 ['01/20/2016 12:30:00 PM',
  '054XX W MONROE ST',
  'BATTERY',
  'SIMPLE',
  'RESIDENCE',
  'false',
  'false',
  '15'],
 ['11/27/2016 02:30:00 AM',
  '020XX S MICHIGAN AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '1'],
 ['03/15/2016 08:14:00 AM',
  '014XX S LAWNDALE AVE',
  'ASSAULT',
  'AGGRAVATED:KNIFE/CUTTING INSTR',
  'ALLEY',
  'true',
  'true',
  '10'],
 ['02/07/2016 07:00:00 PM',
  '076XX S HAMILTON AVE',
  'THEFT',
  '$500 AND UNDER',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '6'],
 ['01/17/2017 02:00:00 PM',
  '034XX N ALBANY AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '17'],
 ['08/31/2016 04:00:00 PM',
  '062XX S WOOD ST',
  'CRIMINAL TRESPASS',
  'TO RESIDENCE',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['04/26/2016 04:29:00 AM',
  '047XX N SHERIDAN RD',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '19'],
 ['09/12/2016 08:00:00 PM',
  '018XX W LELAND AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '19'],
 ['10/23/2016 04:10:00 PM',
  '017XX W 119TH ST',
  'ASSAULT',
  'SIMPLE',
  'RESTAURANT',
  'false',
  'false',
  '22'],
 ['12/19/2016 04:00:00 AM',
  '037XX N BROADWAY',
  'THEFT',
  'FROM BUILDING',
  'BAR OR TAVERN',
  'false',
  'false',
  '19'],
 ['09/05/2016 01:04:00 AM',
  '072XX S EMERALD AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['03/01/2017 07:15:00 PM',
  '042XX W ARMITAGE AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'ALLEY',
  'false',
  'false',
  '25'],
 ['02/29/2016 07:05:00 PM',
  '040XX W 26TH ST',
  'OTHER OFFENSE',
  'VIOLATE ORDER OF PROTECTION',
  'SIDEWALK',
  'false',
  'false',
  '10'],
 ['12/29/2016 10:25:00 AM',
  '017XX N SAYRE AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'false',
  '25'],
 ['11/03/2016 02:08:00 AM',
  '061XX W CORNELIA AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '16'],
 ['04/09/2016 06:25:00 PM',
  '024XX N LINCOLN AVE',
  'THEFT',
  'RETAIL THEFT',
  'DRUG STORE',
  'true',
  'false',
  '19'],
 ['07/29/2016 04:05:00 PM',
  '077XX S LOOMIS BLVD',
  'HOMICIDE',
  'FIRST DEGREE MURDER',
  'STREET',
  'false',
  'false',
  '6'],
 ['06/18/2016 08:00:00 AM',
  '120XX S PERRY AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '5'],
 ['07/03/2016 10:00:00 AM',
  '092XX S MAY ST',
  'THEFT',
  'OVER $500',
  'VACANT LOT/LAND',
  'false',
  'false',
  '22'],
 ['03/12/2016 12:13:00 PM',
  '050XX S MAY ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE',
  'false',
  'false',
  '9'],
 ['04/19/2016 08:15:00 PM',
  '021XX W NORTH AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '14'],
 ['05/30/2016 09:00:00 PM',
  '043XX N NARRAGANSETT AVE',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '16'],
 ['12/18/2016 03:30:00 PM',
  '013XX N AVERS AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '25'],
 ['03/20/2016 10:25:00 AM',
  '051XX S TALMAN AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '9'],
 ['06/18/2016 08:33:00 PM',
  '053XX N LINCOLN AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'APARTMENT',
  'false',
  'false',
  '20'],
 ['12/13/2016 08:57:00 PM',
  '015XX W 18TH ST',
  'BATTERY',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '12'],
 ['09/27/2016 11:30:00 PM',
  '0000X W HUBBARD ST',
  'THEFT',
  'PURSE-SNATCHING',
  'STREET',
  'false',
  'false',
  '18'],
 ['08/31/2016 09:43:00 PM',
  '010XX N LARRABEE ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '18'],
 ['02/07/2017 07:30:00 PM',
  '018XX W WELLINGTON AVE',
  'OTHER OFFENSE',
  'FALSE/STOLEN/ALTERED TRP',
  'STREET',
  'false',
  'false',
  '19'],
 ['12/17/2016 02:25:00 PM',
  '004XX S RACINE AVE',
  'THEFT',
  'PURSE-SNATCHING',
  'SIDEWALK',
  'false',
  'false',
  '12'],
 ['07/23/2016 11:45:00 PM',
  '046XX S WASHTENAW AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '9'],
 ['07/04/2016 10:35:00 PM',
  '004XX E 33RD PL',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '2'],
 ['01/02/2017 08:00:00 AM',
  '001XX S ABERDEEN ST',
  'THEFT',
  'OVER $500',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '12'],
 ['01/22/2017 03:38:00 PM',
  '065XX S FAIRFIELD AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '8'],
 ['03/11/2016 09:15:00 AM',
  '002XX E 51ST ST',
  'THEFT',
  '$500 AND UNDER',
  'GAS STATION',
  'true',
  'false',
  '2'],
 ['03/19/2016 11:45:00 PM',
  '050XX W IRVING PARK RD',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'false',
  '16'],
 ['05/25/2016 06:00:00 PM',
  '038XX W 86TH PL',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '8'],
 ['01/31/2016 05:00:00 PM',
  '046XX W PATTERSON AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'false',
  '17'],
 ['01/05/2016 03:40:00 PM',
  '086XX W FOSTER AVE',
  'ASSAULT',
  'SIMPLE',
  'SCHOOL, PUBLIC, GROUNDS',
  'false',
  'false',
  '16'],
 ['01/30/2016 07:00:00 AM',
  '014XX N CLEVELAND AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'false',
  '18'],
 ['01/02/2017 11:40:00 AM',
  '046XX S LAVERGNE AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'OTHER',
  'false',
  'false',
  '8'],
 ['12/12/2016 12:01:00 AM',
  '001XX W 104TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['06/10/2016 10:32:00 PM',
  '091XX S CARPENTER ST',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'STREET',
  'true',
  'false',
  '22'],
 ['06/21/2016 11:00:00 PM',
  '046XX W JACKSON BLVD',
  'BATTERY',
  'SIMPLE',
  'PARK PROPERTY',
  'false',
  'false',
  '11'],
 ['10/03/2016 04:13:00 PM',
  '0000X S HALSTED ST',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '12'],
 ['11/09/2016 02:00:00 PM',
  '082XX S EVANS AVE',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '6'],
 ['11/27/2016 05:30:00 PM',
  '006XX N SAWYER AVE',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'false',
  'false',
  '11'],
 ['04/10/2016 04:53:00 PM',
  '010XX N LAWLER AVE',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'SIDEWALK',
  'true',
  'false',
  '15'],
 ['01/07/2016 07:25:00 AM',
  '043XX N ASHLAND AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '19'],
 ['08/17/2016 12:30:00 PM',
  '074XX S RHODES AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '3'],
 ['02/26/2017 05:00:00 PM',
  '063XX S MOBILE AVE',
  'NARCOTICS',
  'POSS: CANNABIS 30GMS OR LESS',
  'STREET',
  'true',
  'false',
  '8'],
 ['01/03/2017 03:00:00 PM',
  '079XX S STATE ST',
  'THEFT',
  '$500 AND UNDER',
  'GAS STATION',
  'false',
  'true',
  '6'],
 ['08/06/2016 10:50:00 PM',
  '011XX S ST LOUIS AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'SIDEWALK',
  'false',
  'true',
  '11'],
 ['02/24/2017 09:45:00 PM',
  '005XX N LECLAIRE AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '15'],
 ['03/19/2016 05:00:00 PM',
  '021XX N CLARK ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  '',
  'false',
  'false',
  '18'],
 ['10/03/2016 05:50:00 PM',
  '075XX S STONY ISLAND AVE',
  'ROBBERY',
  'ATTEMPT: STRONGARM-NO WEAPON',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '4'],
 ['06/20/2016 11:45:00 PM',
  '0000X E MADISON ST',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'CONVENIENCE STORE',
  'false',
  'false',
  '1'],
 ['06/08/2016 07:40:00 PM',
  '037XX N WESTERN AVE',
  'KIDNAPPING',
  'CHILD ABDUCTION/STRANGER',
  'SIDEWALK',
  'false',
  'false',
  '19'],
 ['05/08/2016 12:00:00 PM',
  '057XX S ELIZABETH ST',
  'DECEPTIVE PRACTICE',
  'FRAUD OR CONFIDENCE GAME',
  'RESIDENCE',
  'false',
  'false',
  '7'],
 ['09/04/2016 08:12:00 AM',
  '063XX S DR MARTIN LUTHER KING JR DR',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'true',
  'true',
  '3'],
 ['01/11/2016 04:24:00 PM',
  '112XX S MICHIGAN AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'PAWN SHOP',
  'false',
  'false',
  '5'],
 ['06/10/2016 01:40:00 PM',
  '022XX W WALNUT ST',
  'THEFT',
  'OVER $500',
  'SMALL RETAIL STORE',
  'false',
  'false',
  '12'],
 ['08/08/2016 07:00:00 PM',
  '041XX W 21ST PL',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'RESIDENCE',
  'false',
  'false',
  '10'],
 ['09/10/2016 02:00:00 PM',
  '006XX S WABASH AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE',
  'false',
  'false',
  '1'],
 ['11/06/2016 12:00:00 PM',
  '025XX W HADDON AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'APARTMENT',
  'false',
  'false',
  '12'],
 ['01/06/2017 12:15:00 AM',
  '0000X N LARAMIE AVE',
  'ROBBERY',
  'ARMED: HANDGUN',
  'SIDEWALK',
  'false',
  'false',
  '15'],
 ['11/15/2016 09:30:00 AM',
  '056XX N KIMBALL AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'true',
  'false',
  '17'],
 ['09/16/2016 03:30:00 PM',
  '016XX W BELMONT AVE',
  'THEFT',
  'OVER $500',
  'CTA BUS',
  'false',
  'false',
  '19'],
 ['01/28/2016 12:05:00 AM',
  '064XX S CHAMPLAIN AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'true',
  'false',
  '3'],
 ['05/28/2016 02:00:00 PM',
  '012XX W CORNELIA AVE',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '19'],
 ['08/09/2016 07:00:00 PM',
  '040XX N PULASKI RD',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '17'],
 ['01/19/2017 11:00:00 PM',
  '043XX W HIRSCH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '25'],
 ['08/06/2016 06:30:00 PM',
  '017XX W PEARSON ST',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '12'],
 ['11/04/2016 01:00:00 PM',
  '008XX E 49TH ST',
  'BURGLARY',
  'UNLAWFUL ENTRY',
  'APARTMENT',
  'false',
  'false',
  '2'],
 ['07/07/2016 06:00:00 PM',
  '018XX S KILDARE AVE',
  'BATTERY',
  'AGGRAVATED: OTHER DANG WEAPON',
  'STREET',
  'false',
  'false',
  '10'],
 ['11/08/2016 09:00:00 PM',
  '085XX S KILBOURN AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '8'],
 ['06/06/2016 09:00:00 PM',
  '006XX E 88TH PL',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '6'],
 ['08/16/2016 10:45:00 PM',
  '010XX W MARQUETTE RD',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'true',
  'true',
  '7'],
 ['02/15/2016 01:07:00 PM',
  '010XX N LOCKWOOD AVE',
  'OTHER OFFENSE',
  'TELEPHONE THREAT',
  'RESIDENCE',
  'false',
  'true',
  '15'],
 ['05/07/2016 08:55:00 PM',
  '042XX W FILLMORE ST',
  'OTHER OFFENSE',
  'HARASSMENT BY ELECTRONIC MEANS',
  'RESIDENCE',
  'false',
  'false',
  '11'],
 ['07/11/2016 09:00:00 AM',
  '097XX S INDIANA AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['01/13/2017 04:00:00 PM',
  '071XX S EAST END AVE',
  'OFFENSE INVOLVING CHILDREN',
  'OTHER OFFENSE',
  'APARTMENT',
  'false',
  'true',
  '3'],
 ['05/15/2016 07:00:00 AM',
  '001XX W MAPLE ST',
  'BATTERY',
  'SIMPLE',
  'OTHER',
  'false',
  'false',
  '18'],
 ['06/02/2016 01:30:00 PM',
  '011XX S HOMAN AVE',
  'BATTERY',
  'PRO EMP HANDS NO/MIN INJURY',
  'SCHOOL, PRIVATE, BUILDING',
  'false',
  'false',
  '11'],
 ['07/02/2016 02:00:00 AM',
  '009XX N HOWE ST',
  'DECEPTIVE PRACTICE',
  'COUNTERFEITING DOCUMENT',
  'STREET',
  'false',
  'false',
  '18'],
 ['10/06/2016 10:00:00 PM',
  '027XX W HADDON AVE',
  'THEFT',
  '$500 AND UNDER',
  'VEHICLE NON-COMMERCIAL',
  'false',
  'false',
  '12'],
 ['06/13/2016 07:50:00 AM',
  '026XX N HALSTED ST',
  'THEFT',
  'OVER $500',
  'APARTMENT',
  'false',
  'false',
  '19'],
 ['11/28/2016 12:35:00 PM',
  '041XX W MADISON ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'SIDEWALK',
  'false',
  'false',
  '11'],
 ['10/07/2016 10:30:00 PM',
  '048XX W MADISON ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'true',
  '15'],
 ['10/31/2016 12:01:00 AM',
  '008XX N RIDGEWAY AVE',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'RESIDENCE',
  'false',
  'false',
  '11'],
 ['02/29/2016 09:35:00 PM',
  '110XX S GREEN ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '22'],
 ['12/07/2016 07:49:00 PM',
  '064XX S DR MARTIN LUTHER KING JR DR',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'APARTMENT',
  'false',
  'true',
  '3'],
 ['02/27/2017 06:00:00 PM',
  '029XX N SHERIDAN RD',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '19'],
 ['06/04/2016 08:50:00 PM',
  '004XX W EVERGREEN AVE',
  'NARCOTICS',
  'POSS: CRACK',
  'SIDEWALK',
  'true',
  'false',
  '18'],
 ['02/01/2017 09:15:00 AM',
  '002XX W 108TH ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['09/01/2016 08:15:00 PM',
  '076XX S RACINE AVE',
  'ASSAULT',
  'SIMPLE',
  'STREET',
  'true',
  'false',
  '6'],
 ['01/27/2016 10:30:00 PM',
  '051XX S LAKE PARK AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'true',
  '2'],
 ['12/01/2016 03:37:00 PM',
  '092XX S COMMERCIAL AVE',
  'OTHER OFFENSE',
  'VEHICLE TITLE/REG OFFENSE',
  'STREET',
  'true',
  'false',
  '4'],
 ['04/16/2016 09:15:00 PM',
  '044XX W WASHINGTON BLVD',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '11'],
 ['09/13/2016 02:00:00 AM',
  '103XX S CALHOUN AVE',
  'OFFENSE INVOLVING CHILDREN',
  'AGG CRIM SEX ABUSE FAM MEMBER',
  'RESIDENCE',
  'false',
  'true',
  '4'],
 ['02/06/2017 03:40:00 PM',
  '024XX W 71ST ST',
  'BATTERY',
  'AGGRAVATED: HANDGUN',
  'ALLEY',
  'false',
  'false',
  '8'],
 ['11/13/2016 04:00:00 PM',
  '053XX S INDIANA AVE',
  'OTHER OFFENSE',
  'OTHER VEHICLE OFFENSE',
  'STREET',
  'false',
  'false',
  '2'],
 ['01/03/2017 01:15:00 PM',
  '051XX S CICERO AVE',
  'DECEPTIVE PRACTICE',
  'CREDIT CARD FRAUD',
  'RESTAURANT',
  'false',
  'false',
  '8'],
 ['05/27/2016 10:30:00 PM',
  '044XX N KIMBALL AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'true',
  'false',
  '17'],
 ['08/06/2016 10:30:00 AM',
  '079XX S KENWOOD AVE',
  'THEFT',
  '$500 AND UNDER',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['07/28/2016 10:05:00 PM',
  '054XX S WINCHESTER AVE',
  'WEAPONS VIOLATION',
  'UNLAWFUL POSS OF HANDGUN',
  'SIDEWALK',
  'true',
  'false',
  '9'],
 ['08/26/2016 10:00:00 PM',
  '007XX W IRVING PARK RD',
  'THEFT',
  'OVER $500',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'false',
  '19'],
 ['03/18/2016 01:00:00 AM',
  '027XX S CALIFORNIA AVE',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'GOVERNMENT BUILDING/PROPERTY',
  'false',
  'false',
  '10'],
 ['02/16/2016 10:30:00 PM',
  '022XX W FULLERTON AVE',
  'THEFT',
  '$500 AND UNDER',
  'ALLEY',
  'false',
  'false',
  '14'],
 ['01/13/2017 01:40:00 AM',
  '001XX W 116TH ST',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '5'],
 ['10/15/2016 12:04:00 AM',
  '015XX W HURON ST',
  'OTHER OFFENSE',
  'HARASSMENT BY TELEPHONE',
  'RESIDENCE',
  'false',
  'false',
  '12'],
 ['01/27/2016 07:35:00 PM',
  '062XX S MORGAN ST',
  'BATTERY',
  'AGG: HANDS/FIST/FEET SERIOUS INJURY',
  'STREET',
  'true',
  'false',
  '7'],
 ['10/19/2016 11:00:00 AM',
  '008XX S KEDZIE AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENCE-GARAGE',
  'false',
  'false',
  '11'],
 ['10/30/2016 07:00:00 AM',
  '032XX W 87TH ST',
  'THEFT',
  'RETAIL THEFT',
  'GROCERY FOOD STORE',
  'true',
  'false',
  '8'],
 ['01/28/2017 04:00:00 PM',
  '081XX S MORGAN ST',
  'ROBBERY',
  'AGGRAVATED VEHICULAR HIJACKING',
  'STREET',
  'false',
  'false',
  '6'],
 ['02/19/2017 09:00:00 PM',
  '027XX W TOUHY AVE',
  'CRIMINAL DAMAGE',
  'TO VEHICLE',
  'STREET',
  'false',
  'false',
  '24'],
 ['06/07/2016 04:50:00 AM',
  '085XX S ST LAWRENCE AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '6'],
 ['06/24/2016 11:40:00 AM',
  '013XX S KARLOV AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE',
  'false',
  'true',
  '10'],
 ['03/19/2016 04:55:00 AM',
  '067XX S INDIANA AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'true',
  '3'],
 ['11/21/2016 10:00:00 PM',
  '013XX W TOUHY AVE',
  'THEFT',
  '$500 AND UNDER',
  'APARTMENT',
  'false',
  'false',
  '24'],
 ['11/24/2016 02:51:00 PM',
  '023XX N MOODY AVE',
  'ASSAULT',
  'SIMPLE',
  'RESIDENTIAL YARD (FRONT/BACK)',
  'false',
  'true',
  '25'],
 ['01/14/2016 02:00:00 AM',
  '028XX S QUINN ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '9'],
 ['05/20/2016 06:15:00 PM',
  '028XX W FIFTH AVE',
  'NARCOTICS',
  'MANU/DELIVER: HEROIN (WHITE)',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['06/15/2016 01:30:00 PM',
  '001XX S MICHIGAN AVE',
  'THEFT',
  'FROM BUILDING',
  'RESTAURANT',
  'false',
  'false',
  '1'],
 ['08/06/2016 01:16:00 PM',
  '007XX N TRUMBULL AVE',
  'NARCOTICS',
  'MANU/DELIVER: HEROIN (WHITE)',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['01/08/2016 10:50:00 AM',
  '009XX E 82ND ST',
  'CRIMINAL DAMAGE',
  'TO PROPERTY',
  'STREET',
  'false',
  'true',
  '6'],
 ['02/21/2017 03:00:00 PM',
  '003XX E 44TH ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '2'],
 ['02/18/2016 09:00:00 AM',
  '026XX S TROY ST',
  'DECEPTIVE PRACTICE',
  'FINANCIAL IDENTITY THEFT OVER $ 300',
  'RESIDENCE',
  'false',
  'false',
  '10'],
 ['06/02/2016 01:00:00 PM',
  '062XX S KENNETH AVE',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'RESIDENCE PORCH/HALLWAY',
  'false',
  'true',
  '8'],
 ['01/05/2016 03:55:00 AM',
  '005XX W 119TH ST',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'GROCERY FOOD STORE',
  'false',
  'false',
  '5'],
 ['10/06/2016 09:00:00 PM',
  '027XX E 75TH PL',
  'BATTERY',
  'DOMESTIC BATTERY SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '4'],
 ['05/10/2016 06:00:00 PM',
  '034XX N CICERO AVE',
  'BURGLARY',
  'FORCIBLE ENTRY',
  'SCHOOL, PRIVATE, BUILDING',
  'false',
  'false',
  '17'],
 ['02/28/2016 10:25:00 PM',
  '012XX S MICHIGAN AVE',
  'ASSAULT',
  'SIMPLE',
  'SIDEWALK',
  'false',
  'false',
  '1'],
 ['01/25/2016 11:22:00 AM',
  '003XX E 47TH ST',
  'LIQUOR LAW VIOLATION',
  'LIQUOR LICENSE VIOLATION',
  'TAVERN/LIQUOR STORE',
  'true',
  'false',
  '2'],
 ['03/13/2016 08:45:00 AM',
  '075XX S GREEN ST',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '6'],
 ['05/09/2016 06:30:00 PM',
  '053XX N CHRISTIANA AVE',
  'DECEPTIVE PRACTICE',
  'ATTEMPT - FINANCIAL IDENTITY THEFT',
  'RESIDENCE',
  'false',
  'false',
  '17'],
 ['11/21/2016 08:00:00 AM',
  '081XX S CORNELL AVE',
  'THEFT',
  'FROM BUILDING',
  'RESIDENCE',
  'false',
  'false',
  '4'],
 ['05/13/2016 06:00:00 AM',
  '0000X E 21ST ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '1'],
 ['04/06/2016 10:00:00 AM',
  '020XX W WASHINGTON BLVD',
  'THEFT',
  'OVER $500',
  'PARKING LOT/GARAGE(NON.RESID.)',
  'false',
  'false',
  '12'],
 ['02/21/2017 08:05:00 PM',
  '007XX S CENTRAL PARK AVE',
  'NARCOTICS',
  'MANU/DELIVER: HEROIN (WHITE)',
  'SIDEWALK',
  'true',
  'false',
  '11'],
 ['09/12/2016 11:27:00 AM',
  '096XX S CALHOUN AVE',
  'OTHER OFFENSE',
  'PAROLE VIOLATION',
  'SIDEWALK',
  'true',
  'false',
  '4'],
 ['08/28/2016 02:57:00 AM',
  '124XX S WALLACE ST',
  'ASSAULT',
  'AGG PO HANDS NO/MIN INJURY',
  'ALLEY',
  'true',
  'false',
  '5'],
 ['02/21/2016 01:30:00 PM',
  '038XX W LELAND AVE',
  'BATTERY',
  'SIMPLE',
  'APARTMENT',
  'false',
  'false',
  '17'],
 ['10/18/2016 07:30:00 PM',
  '014XX W WEBSTER AVE',
  'THEFT',
  'OVER $500',
  'STREET',
  'false',
  'false',
  '18'],
 ['04/29/2016 08:20:00 AM',
  '120XX S MICHIGAN AVE',
  'NARCOTICS',
  'FOUND SUSPECT NARCOTICS',
  'RESIDENCE',
  'true',
  'false',
  '5'],
 ['10/05/2016 11:45:00 AM',
  '040XX W ARMITAGE AVE',
  'ROBBERY',
  'ARMED:KNIFE/CUTTING INSTRUMENT',
  'SIDEWALK',
  'false',
  'false',
  '25'],
 ['11/25/2016 12:15:00 PM',
  '008XX W SUPERIOR ST',
  'THEFT',
  '$500 AND UNDER',
  'STREET',
  'false',
  'false',
  '12'],
 ['09/12/2016 04:00:00 PM',
  '035XX S RHODES AVE',
  'MOTOR VEHICLE THEFT',
  'AUTOMOBILE',
  'STREET',
  'false',
  'false',
  '2'],
 ['03/29/2016 10:35:00 PM',
  '067XX S SPRINGFIELD AVE',
  'ROBBERY',
  'STRONGARM - NO WEAPON',
  'SIDEWALK',
  'false',
  'false',
  '8'],
 ['01/14/2017 03:57:00 PM',
  '023XX S DR MARTIN LUTHER KING JR DR',
  'THEFT',
  'POCKET-PICKING',
  'OTHER',
  'false',
  'false',
  '1'],
 ['05/27/2016 11:50:00 AM',
  '075XX S EMERALD AVE',
  'ROBBERY',
  'ATTEMPT: ARMED-HANDGUN',
  'ALLEY',
  'false',
  'false',
  '6']]
# Import necessary modules
from collections import Counter
from datetime import datetime

# Create a Counter Object: crimes_by_month
crimes_by_month = Counter()

# Loop over the crime_data list
for item in crime_data:
    
    # Convert the first element of each item into a Python Datetime Object: date
    date = datetime.strptime(item[0], '%m/%d/%Y %I:%M:%S %p')
    
    # Increment the counter for the month of the row by one
    crimes_by_month[date.month] += 1
    
# Print the 3 most common months for crime
print(crimes_by_month.most_common(3))
# Out:
# [(1, 143), (2, 112), (8, 100)]
